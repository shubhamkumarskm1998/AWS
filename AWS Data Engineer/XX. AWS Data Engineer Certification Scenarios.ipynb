# %% [markdown]
# ## ❓ Question
# A data engineer runs an AWS Glue job inside a VPC to read data from an S3 bucket. The job fails with an error related to the S3 VPC gateway endpoint. What should be fixed?
#
# ---
#
# ## 📌 Topic
# VPC Endpoints (Private S3 Access)
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - Amazon S3
# - Amazon VPC (Gateway Endpoint)
#
# ---
#
# ## ⚠️ Issue
# Glue job inside VPC cannot reach S3 due to incorrect/missing S3 VPC endpoint configuration.
#
# ---
#
# ## ✅ Solution
# - Ensure **S3 Gateway Endpoint** exists
# - Attach it to the **correct route table** used by Glue subnets
# - Verify **endpoint policy + IAM role** allow S3 access
#
# ---
#
# ## 💡 Exam Hint
# If a service in VPC cannot access S3 → **Check S3 VPC Endpoint / Route Table**

# %% [markdown]
# ## ❓ Question
# A data engineer manages a customer data lake in S3 accessed by analysts across multiple countries. Governance requires that analysts can only access data from their own country. How can this be enforced?
#
# ---
#
# ## 📌 Topic
# Data Governance & Fine-Grained Access Control
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - AWS Lake Formation
# - AWS IAM
#
# ---
#
# ## ⚠️ Issue
# Need to restrict access so users only see data belonging to their country.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Lake Formation**
# - Implement **row-level or column-level security** based on country
# - Tag data (LF-Tags) and grant access accordingly
# - Alternatively, enforce using **IAM policies with S3 prefixes** (country-wise folders)
#
# ---
#
# ## 💡 Exam Hint
# Country-based data restriction → **Lake Formation (fine-grained access control)**

# %% [markdown]
# ## ❓ Question
# A data engineer needs to integrate third-party datasets into an existing analytics platform to improve personalization, while minimizing development time and maintenance effort. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Ingestion (Third-Party Data Integration)
#
# ---
#
# ## 🛠️ Services
# - AWS Data Exchange
# - Amazon S3
# - AWS Glue (optional for processing)
#
# ---
#
# ## ⚠️ Issue
# Need easy integration of external datasets with minimal engineering effort.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Data Exchange** to subscribe and import third-party datasets directly into S3
# - Integrate with existing analytics platform without building custom pipelines
#
# ---
#
# ## 💡 Exam Hint
# Third-party datasets + minimal effort → **AWS Data Exchange**

# %% [markdown]
# ## ❓ Question
# A data engineer is implementing a data mesh architecture to decentralize data ownership while maintaining centralized governance. What is the best AWS solution?
#
# ---
#
# ## 📌 Topic
# Data Governance in Distributed Architecture (Data Mesh)
#
# ---
#
# ## 🛠️ Services
# - AWS Lake Formation
# - AWS Glue Data Catalog
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Need decentralized data ownership with centralized governance control.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Lake Formation** for centralized governance
# - Enable **cross-account data sharing** for domain-based ownership
# - Use **Glue Data Catalog** for metadata management
#
# ---
#
# ## 💡 Exam Hint
# Data Mesh (decentralized + governance) → **Lake Formation + Cross-account sharing**

# %% [markdown]
# ## ❓ Question
# A data engineer maintains multiple AWS Lambda functions that rely on the same custom Python scripts for data formatting. What is the best way to manage this shared code?
#
# ---
#
# ## 📌 Topic
# Code Reusability & Serverless Architecture
#
# ---
#
# ## 🛠️ Services
# - AWS Lambda
# - Lambda Layers
#
# ---
#
# ## ⚠️ Issue
# Same code is duplicated across multiple Lambda functions → hard to maintain.
#
# ---
#
# ## ✅ Solution
# - Create a **Lambda Layer** with the shared Python scripts
# - Attach the layer to all Lambda functions
# - Update code centrally in one place
#
# ---
#
# ## 💡 Exam Hint
# Shared code across Lambdas → **Lambda Layers**

# %% [markdown]
# ## ❓ Question
# A data engineer builds an AWS Glue ETL pipeline to extract data from Microsoft SQL Server, transform it, and load it into Amazon S3. What is the best way to connect Glue to SQL Server?
#
# ---
#
# ## 📌 Topic
# Data Ingestion (Database → S3 using Glue)
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - Amazon S3
# - Amazon RDS / SQL Server (or on-prem)
# - AWS Glue Connection
#
# ---
#
# ## ⚠️ Issue
# Glue needs secure connectivity to an external SQL Server database.
#
# ---
#
# ## ✅ Solution
# - Create a **Glue Connection (JDBC)** for SQL Server
# - Configure **VPC, subnet, and security groups** for connectivity
# - Use Glue job to extract → transform → load into S3
#
# ---
#
# ## 💡 Exam Hint
# Glue + external DB → **JDBC Connection + VPC setup**

# %% [markdown]
# ## ❓ Question
# A data engineer needs to enable real-time queries on Amazon Redshift data for a web-based trading application. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Low-Latency / Real-Time Querying
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
# - Amazon Redshift Data API / Query Editor v2
# - (Optional) Amazon API Gateway + Lambda
#
# ---
#
# ## ⚠️ Issue
# Application needs fast, real-time access to Redshift data.
#
# ---
#
# ## ✅ Solution
# - Use **Redshift Data API** to run queries directly from the application
# - Optionally integrate via **API Gateway + Lambda** for web access
#
# ---
#
# ## 💡 Exam Hint
# App querying Redshift in real-time → **Redshift Data API**

# %% [markdown]
# ## ❓ Question
# A data engineer manages multiple Amazon Athena query use cases within the same AWS account. How can they organize and isolate these workloads efficiently?
#
# ---
#
# ## 📌 Topic
# Query Workload Isolation & Management
#
# ---
#
# ## 🛠️ Services
# - Amazon Athena
# - AWS IAM
# - AWS Workgroups
#
# ---
#
# ## ⚠️ Issue
# Multiple teams/use cases using Athena in same account → need separation, cost control, and governance.
#
# ---
#
# ## ✅ Solution
# - Use **Athena Workgroups** to separate workloads
# - Configure:
#   - Different query result locations (S3)
#   - Per-workgroup limits (cost control)
#   - IAM policies for access control
#
# ---
#
# ## 💡 Exam Hint
# Multiple Athena users/use cases → **Athena Workgroups**

# %% [markdown]
# ## ❓ Question
# A data engineer needs to schedule a daily AWS Glue workflow that runs multiple ETL jobs with minimal cost. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Cost Optimization in ETL Processing
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - AWS Glue Flex Jobs
# - (Optional) Glue Triggers / Scheduler
#
# ---
#
# ## ⚠️ Issue
# Daily ETL jobs need to run at **lowest possible cost**.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue Flex Jobs**
#   - Lower cost compared to standard jobs
#   - Suitable for **non-urgent workloads**
# - Schedule using Glue triggers or EventBridge
#
# ---
#
# ## 💡 Exam Hint
# If question stresses **“minimal cost”** → **Glue Flex Jobs** (accepts delays for cheaper execution)

# %% [markdown]
# ## ❓ Question
# A data engineer needs to automatically convert CSV files to Parquet whenever new files are uploaded to Amazon S3. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Event-Driven Data Processing
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - AWS Lambda
# - AWS Glue (optional for larger workloads)
# - Amazon EventBridge / S3 Event Notifications
#
# ---
#
# ## ⚠️ Issue
# Need automatic transformation triggered on file upload.
#
# ---
#
# ## ✅ Solution
# - Configure **S3 Event Notification** on object upload
# - Trigger **AWS Lambda** to convert CSV → Parquet (for small/medium files)
# - For large-scale data, trigger an **AWS Glue job** instead
#
# ---
#
# ## 💡 Exam Hint
# S3 upload trigger → **Lambda (event-driven processing)**
# Large data → **Glue**

# %% [markdown]
# ## ❓ Question
# Athena queries are slow on uncompressed CSV data filtered by a specific column. How can performance be improved?
#
# ---
#
# ## 📌 Topic
# Query Performance Optimization (Athena)
#
# ---
#
# ## 🛠️ Services
# - Amazon Athena
# - Amazon S3
# - AWS Glue (for ETL)
#
# ---
#
# ## ⚠️ Issue
# CSV + no compression + column filtering → high scan cost and slow queries.
#
# ---
#
# ## ✅ Solution
# - Convert data to **Parquet (columnar format)**
# - Apply **compression (Snappy/Gzip)**
# - Partition data based on the **filter column**
#
# ---
#
# ## 💡 Exam Hint
# Athena slow + CSV → **Use Parquet + Partitioning**

# %% [markdown]
# ## ❓ Question
# A data engineer collects sensor data using Kinesis Data Streams and needs real-time visualization. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Real-Time Stream Processing
#
# ---
#
# ## 🛠️ Services
# - Amazon Kinesis Data Streams
# - Amazon Managed Service for Apache Flink
# - Amazon QuickSight (or downstream store like S3/Redshift)
#
# ---
#
# ## ⚠️ Issue
# Need real-time processing + analytics on streaming data.
#
# ---
#
# ## ✅ Solution
# - Use **Amazon Managed Service for Apache Flink** (formerly Kinesis Data Analytics)
# - Process and aggregate streaming data in real time
# - Send output to a datastore (S3/Redshift) and visualize via QuickSight
#
# ---
#
# ## 💡 Exam Hint
# Streaming + real-time processing → **Flink (Managed Service for Apache Flink)**

# %% [markdown]
# ## ❓ Question
# A data engineer manages daily CSV files in S3 that must be crawled and registered automatically. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Metadata Management & Data Cataloging
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - AWS Glue Crawler
# - AWS Glue Data Catalog
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Need automatic schema discovery and table registration for new files.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue Crawler** on S3 path
# - Schedule crawler to run daily
# - Automatically update **Glue Data Catalog tables**
#
# ---
#
# ## 💡 Exam Hint
# “Crawl + register data” → **Glue Crawler**

# %% [markdown]
# ## ❓ Question
# A data engineer needs to track Amazon Redshift table load status and automatically log success/failure. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Monitoring & Logging
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
# - Amazon CloudWatch
# - Amazon EventBridge (optional)
#
# ---
#
# ## ⚠️ Issue
# Need automated tracking of load operations (success/failure).
#
# ---
#
# ## ✅ Solution
# - Use **Redshift system tables** (like STL_LOAD_COMMITS / STL_LOAD_ERRORS) to track load status
# - Send logs/metrics to **CloudWatch**
# - Optionally trigger alerts using **EventBridge**
#
# ---
#
# ## 💡 Exam Hint
# Redshift load monitoring → **System tables + CloudWatch**

# %% [markdown]
# ## ❓ Question
# A data engineer must automate secure transfer of 5 TB of data from on-premises to Amazon S3 with incremental sync. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Migration & Transfer
#
# ---
#
# ## 🛠️ Services
# - AWS DataSync
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Large data transfer (TBs) + need automation + incremental updates.
#
# ---
#
# ## ✅ Solution
# - Use **AWS DataSync**
# - Supports **incremental data transfer**
# - Provides **secure, fast, and automated syncing** from on-prem to S3
#
# ---
#
# ## 💡 Exam Hint
# Large data + incremental sync → **AWS DataSync**

# %% [markdown]
# ## ❓ Question
# A data engineer migrates data monthly from on-premises SQL Server to Amazon RDS for SQL Server, but it is costly and time-consuming. They need a cost-effective solution with minimal downtime. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Database Migration (Low Downtime)
#
# ---
#
# ## 🛠️ Services
# - AWS Database Migration Service (DMS)
# - Amazon RDS (SQL Server)
# - AWS Schema Conversion Tool (optional)
#
# ---
#
# ## ⚠️ Issue
# Bulk migrations are slow, expensive, and cause downtime.
#
# ---
#
# ## ✅ Solution
# - Use **AWS DMS** with:
#   - **Full load + CDC (Change Data Capture)**
# - Perform initial load, then continuously sync changes
# - Minimizes downtime during cutover
#
# ---
#
# ## 💡 Exam Hint
# Migration + low downtime → **DMS with CDC**

# %% [markdown]
# ## ❓ Question
# A data engineer builds an hourly AWS Glue ETL pipeline to extract from Amazon RDS and MongoDB, transform, and load into Redshift. The solution must be automated, low-maintenance, support secure connections, and scheduled execution. What is the best solution?
#
# ---
#
# ## 📌 Topic
# ETL Pipeline Orchestration & Secure Connectivity
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - AWS Glue Workflows / Triggers
# - Amazon RDS
# - Amazon Redshift
# - AWS Secrets Manager
# - Amazon VPC
#
# ---
#
# ## ⚠️ Issue
# Need automated scheduling, secure DB connections, and minimal maintenance.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue Jobs** with **Glue Workflows/Triggers** for hourly scheduling
# - Store credentials in **AWS Secrets Manager**
# - Use **Glue Connections** with VPC for secure access to RDS & MongoDB
# - Load output into Redshift
#
# ---
#
# ## 💡 Exam Hint
# Secure + scheduled Glue ETL → **Glue Workflows + Secrets Manager + Connections**

# %% [markdown]
# ## ❓ Question
# An Amazon Redshift cluster (RA3) faces query performance issues during heavy workloads due to limited concurrency. The engineer needs automatic scaling to handle spikes in query volume. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Performance Optimization & Auto Scaling (Redshift)
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
# - Redshift Concurrency Scaling
# - (Optional) Workload Management (WLM)
#
# ---
#
# ## ⚠️ Issue
# High query load → limited concurrency → performance degradation.
#
# ---
#
# ## ✅ Solution
# - Enable **Redshift Concurrency Scaling**
# - Automatically adds extra clusters to handle query spikes
# - Improves performance without manual intervention
#
# ---
#
# ## 💡 Exam Hint
# Redshift + concurrency issue → **Concurrency Scaling**

# %% [markdown]
# ## ❓ Question
# A data engineer needs to orchestrate multiple Amazon Athena queries that run daily, some lasting over 15 minutes. The solution must be automated, cost-effective, and support sequential execution. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Workflow Orchestration (Long-Running Tasks)
#
# ---
#
# ## 🛠️ Services
# - AWS Step Functions
# - Amazon Athena
# - AWS Lambda (to trigger queries)
#
# ---
#
# ## ⚠️ Issue
# Athena queries are long-running (>15 min), so simple Lambda orchestration is not suitable.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Step Functions** to orchestrate workflows
# - Trigger Athena queries via Lambda
# - Use **wait + polling pattern** for query completion
# - Supports sequential execution and automation
#
# ---
#
# ## 💡 Exam Hint
# Long-running workflows (>15 min) → **Step Functions (not Lambda alone)**

# %% [markdown]
# ## ❓ Question
# A company is migrating big data workloads (Apache Pig, Oozie, Spark, HBase, Flink) from on-premises to AWS. They process petabytes of data and want serverless or managed solutions with minimal operational overhead while maintaining high performance. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Big Data Processing (Managed Hadoop/Spark Ecosystem)
#
# ---
#
# ## 🛠️ Services
# - Amazon EMR (EMR on EC2 / EMR Serverless)
# - Amazon EMR Serverless
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Need to run Hadoop ecosystem tools with minimal management overhead and high scalability.
#
# ---
#
# ## ✅ Solution
# - Use **Amazon EMR Serverless** (preferred for minimal ops)
# - Alternatively use **Amazon EMR** (managed cluster)
# - Store data in **Amazon S3** for scalable data lake
#
# ---
#
# ## 💡 Exam Hint
# Hadoop ecosystem (Pig, Spark, HBase, Flink) → **Amazon EMR / EMR Serverless**

# %% [markdown]
# ## ❓ Question
# A data engineer is ingesting datasets into an S3 data lake. The data contains PII that must be automatically detected and obfuscated before storage with minimal maintenance. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Security & PII Detection
#
# ---
#
# ## 🛠️ Services
# - Amazon Macie
# - AWS Glue (optional for transformation)
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Need automated detection and masking of sensitive data (PII).
#
# ---
#
# ## ✅ Solution
# - Use **Amazon Macie** to automatically detect PII in S3
# - Integrate with **Glue/Lambda** to mask or obfuscate sensitive data before/after ingestion
#
# ---
#
# ## 💡 Exam Hint
# PII detection → **Amazon Macie**

# %% [markdown]
# ## ❓ Question
# A company runs multiple ETL pipelines using AWS Glue and Amazon EMR to process data into an S3 data lake. They want to automate orchestration to reduce manual coordination and improve reliability. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Workflow Orchestration (Multi-Service Pipelines)
#
# ---
#
# ## 🛠️ Services
# - AWS Step Functions
# - AWS Glue
# - Amazon EMR
#
# ---
#
# ## ⚠️ Issue
# Need orchestration across **multiple services (Glue + EMR)** with reliability.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Step Functions**
# - Orchestrate both **Glue and EMR jobs** with retries, dependencies, and error handling
#
# ---
#
# ## ❌ Why NOT Glue Workflows
# - Glue Workflows are mainly for **Glue jobs only**
# - Limited support for orchestrating **EMR and other services**
#
# ---
#
# ## 💡 Exam Hint
# If multiple AWS services involved → **Step Functions**
# If only Glue → **Glue Workflows**

# %% [markdown]
# ## ❓ Question
# Data in an S3 bucket is frequently accessed for 6 months, infrequently accessed for the next 18 months, and rarely accessed after 2 years. How should a lifecycle policy be designed to minimize cost while maintaining availability?
#
# ---
#
# ## 📌 Topic
# Storage Optimization (S3 Lifecycle Policies)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - S3 Storage Classes
# - S3 Lifecycle Policies
#
# ---
#
# ## ⚠️ Issue
# Different access patterns over time → need cost-efficient storage transitions.
#
# ---
#
# ## ✅ Solution
# - Configure **S3 Lifecycle Policy**:
#   - Move to **S3 Standard-IA** after 6 months
#   - Move to **S3 Glacier Flexible Retrieval / Glacier Instant Retrieval** after 18 months
#   - Move to **S3 Glacier Deep Archive** after 2 years
#
# ---
#
# ## 💡 Exam Hint
# Time-based access pattern → **S3 Lifecycle + Storage Class transitions**

# %% [markdown]
# ## ❓ Question
# A data engineer manages an ETL Amazon Redshift cluster. A separate BI cluster needs access to this data for weekly summaries without impacting the ETL cluster’s performance. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Sharing & Workload Isolation (Redshift)
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
# - Redshift Data Sharing
#
# ---
#
# ## ⚠️ Issue
# Need cross-cluster access without increasing load on ETL cluster.
#
# ---
#
# ## ✅ Solution
# - Use **Redshift Data Sharing**
# - Share data from ETL cluster to BI cluster
# - Enables **real-time access without data duplication** and without impacting performance
#
# ---
#
# ## 💡 Exam Hint
# Cross-cluster Redshift access → **Redshift Data Sharing**

# %% [markdown]
# ## ❓ Question
# A data engineer must perform a one-time analysis combining data from DynamoDB, RDS, Redshift, and S3. The solution should be serverless, cost-effective, and avoid building ETL pipelines. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Serverless Querying / Federated Queries
#
# ---
#
# ## 🛠️ Services
# - Amazon Athena
# - Athena Federated Query
# - AWS Lambda (connectors)
#
# ---
#
# ## ⚠️ Issue
# Need to query multiple data sources together without ETL.
#
# ---
#
# ## ✅ Solution
# - Use **Amazon Athena Federated Query**
# - Query data across **S3, RDS, DynamoDB, and Redshift** directly
# - No data movement or ETL required
#
# ---
#
# ## 💡 Exam Hint
# Query multiple sources without ETL → **Athena Federated Query**

# %% [markdown]
# ## ❓ Question
# A company runs long-running, performance-critical Apache Spark workloads on Amazon EMR. The solution must balance cost efficiency, reliability, and consistent performance. What is the best approach?
#
# ---
#
# ## 📌 Topic
# Cost Optimization & Reliability (EMR)
#
# ---
#
# ## 🛠️ Services
# - Amazon EMR
# - EC2 On-Demand Instances
# - EC2 Spot Instances
# - AWS Graviton Instances
#
# ---
#
# ## ⚠️ Issue
# Need low cost + high reliability + consistent performance for long-running jobs.
#
# ---
#
# ## ✅ Solution
# - Use **EMR with mixed instance strategy**:
#   - **On-Demand Graviton instances** for **core nodes** (stable + cost-efficient)
#   - **Spot Graviton instances** for **task nodes** (cheap + scalable)
# - Provides better price-performance with ARM-based Graviton
#
# ---
#
# ## 💡 Exam Hint
# EMR optimization → **On-Demand (core) + Spot (task) + Graviton for cost efficiency**

# %% [markdown]
# ## ❓ Question
# A data engineer needs to design a real-time analytics pipeline that ingests several GB/sec using Kinesis Data Streams and delivers data to Amazon Redshift for near real-time insights. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Real-Time Data Ingestion & Streaming to Redshift
#
# ---
#
# ## 🛠️ Services
# - Amazon Kinesis Data Streams
# - Amazon Kinesis Data Firehose
# - Amazon Redshift
#
# ---
#
# ## ⚠️ Issue
# Need high-throughput streaming ingestion and near real-time loading into Redshift.
#
# ---
#
# ## ✅ Solution
# - Use **Kinesis Data Streams** for ingestion
# - Use **Kinesis Data Firehose** to deliver data to Redshift
#   - Firehose handles buffering, batching, and loading automatically
#
# ---
#
# ## 💡 Exam Hint
# Streaming → Redshift → **Kinesis Firehose (managed delivery)**

# %% [markdown]
# ## ❓ Question
# An AWS Glue ETL pipeline prepares S3 data for a QuickSight dashboard. As data grows daily, both Glue jobs and dashboard queries are becoming slower. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Performance Optimization (ETL + Query)
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - Amazon S3
# - Amazon Athena / Amazon Redshift
# - Amazon QuickSight
#
# ---
#
# ## ⚠️ Issue
# Increasing data volume → slower ETL jobs and slower dashboard queries.
#
# ---
#
# ## ✅ Solution
# - Convert data to **Parquet (columnar format)**
# - Apply **partitioning** (e.g., by date)
# - Enable **compression (Snappy)**
# - **Increase Glue workers / DPUs** to speed up ETL processing
# - Partitioned + optimized data improves **QuickSight query performance**
#
# ---
#
# ## 💡 Exam Hint
# Slow ETL + slow queries → **Parquet + Partitioning + Scale Glue workers**

# %% [markdown]
# ## ❓ Question
# A data engineer needs to orchestrate an AWS Step Functions workflow to process many S3 files. Each file must be processed independently and in parallel to speed up execution. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Parallel Processing & Orchestration
#
# ---
#
# ## 🛠️ Services
# - AWS Step Functions
# - Amazon S3
# - AWS Lambda / AWS Glue
#
# ---
#
# ## ⚠️ Issue
# Need to process large number of files **in parallel** with same logic.
#
# ---
#
# ## ✅ Solution
# - Use **Step Functions Map State**
# - Enables **parallel execution** for each file
# - Each iteration processes one file independently
#
# ---
#
# ## 💡 Exam Hint
# Parallel processing in Step Functions → **Map State**

# %% [markdown]
# ## ❓ Question
# A company migrating legacy data to an S3 data lake finds duplicate records. The engineer must detect and remove duplicates using a low-code, serverless approach. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Transformation (Serverless ETL)
#
# ---
#
# ## 🛠️ Services
# - AWS Glue DataBrew
# - AWS Glue ETL JOB (FIND MATCHES)
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Need deduplication with minimal coding and no infrastructure management.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue DataBrew**
# - Apply built-in **data cleaning & deduplication transformations**
# - Fully serverless and low-code
#
# ---
#
# ## 💡 Exam Hint
# Low-code data cleaning → **Glue DataBrew & AWS Glue ETL JOB (FIND MATCHES)**

# %% [markdown]
# ## ❓ Question
# A data engineer uses Redshift Spectrum to query data in S3 and wants to minimize latency and maximize performance. How should the data be structured?
#
# ---
#
# ## 📌 Topic
# Query Performance Optimization (Spectrum)
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift Spectrum
# - Amazon S3
# - AWS Glue Data Catalog
#
# ---
#
# ## ⚠️ Issue
# Poor query performance due to inefficient data format/storage.
#
# ---
#
# ## ✅ Solution
# - Store data in **columnar format (Parquet/ORC)**
# - Apply **partitioning** (e.g., by date or key columns)
# - Use **compression (Snappy)**
#
# ---
#
# ## 💡 Exam Hint
# Spectrum performance → **Parquet + Partitioning**

# %% [markdown]
# ## ❓ Question
# A Lambda function must insert and update records in an Amazon RDS instance located in a private subnet. The connection must be private (no internet) and require minimal maintenance. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Serverless Connectivity (VPC Access)
#
# ---
#
# ## 🛠️ Services
# - AWS Lambda
# - Amazon RDS
# - Amazon VPC
#
# ---
#
# ## ⚠️ Issue
# Lambda needs private access to RDS without using internet/NAT.
#
# ---
#
# ## ✅ Solution
# - Configure **Lambda to run inside the same VPC**
# - Attach it to **private subnets**
# - Use **security groups** to allow access to RDS
# - No NAT Gateway required
#
# ---
#
# ## 💡 Exam Hint
# Lambda → RDS (private) → **Run Lambda in VPC**

# %% [markdown]
# ## ❓ Question
# A data engineer needs to expose a Python script via Amazon API Gateway for a ReactJS app. The script should run only when triggered and return results with minimal infrastructure and management overhead. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Serverless API Integration
#
# ---
#
# ## 🛠️ Services
# - Amazon API Gateway
# - AWS Lambda
#
# ---
#
# ## ⚠️ Issue
# Need on-demand execution with minimal infrastructure.
#
# ---
#
# ## ✅ Solution
# - Deploy the Python script as an **AWS Lambda function**
# - Integrate it with **API Gateway**
# - Lambda runs only when invoked → fully serverless
#
# ---
#
# ## 💡 Exam Hint
# API + Python + minimal ops → **API Gateway + Lambda**

# %% [markdown]
# ## ❓ Question
# A company needs cross-account log delivery where CloudWatch Logs from a production account are streamed to a security account using Kinesis Data Streams. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Cross-Account Streaming & Logging
#
# ---
#
# ## 🛠️ Services
# - Amazon CloudWatch Logs
# - Amazon Kinesis Data Streams
# - AWS IAM (Roles & Policies)
#
# ---
#
# ## ⚠️ Issue
# Need secure cross-account streaming of logs.
#
# ---
#
# ## ✅ Solution
# - Create **Kinesis Data Stream in security account**
# - Configure **CloudWatch Logs subscription filter** in production account
# - Use **cross-account IAM role** to allow publishing to Kinesis
#
# ---
#
# ## 💡 Exam Hint
# Cross-account logs → **Subscription Filter + Kinesis + IAM Role**

# %% [markdown]
# ## ❓ Question
# A data engineer receives daily full JSON snapshots in S3 containing old and new records. They must process only the changed records each day in a cost-efficient, scalable way without reprocessing all data. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Incremental Processing / Change Detection
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - Amazon S3
# - Apache Hudi / Apache Iceberg / Delta Lake (on Glue/EMR)
#
# ---
#
# ## ⚠️ Issue
# Full snapshots → inefficient to process entire dataset daily.
#
# ---
#
# ## ✅ Solution
# - Use **Apache Hudi / Iceberg / Delta Lake** on S3
# - Enable **upserts (CDC-like processing)** to identify and apply only changed records
# - Avoid full reprocessing → improves cost and performance
#
# ---
#
# ## 💡 Exam Hint
# Full snapshots + only process changes → **Hudi / Iceberg (incremental processing)**

# %% [markdown]
# ## ❓ Question
# Athena queries on partitioned S3 data (managed by Glue Data Catalog) are slow due to a very large number of partitions. How can query planning performance be improved?
#
# ---
#
# ## 📌 Topic
# Query Optimization (Partition Management)
#
# ---
#
# ## 🛠️ Services
# - Amazon Athena
# - AWS Glue Data Catalog
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Too many partitions → slow query planning and metadata lookup.
#
# ---
#
# ## ✅ Solution
# - Use **Partition Indexes (Glue Data Catalog)**
# - Alternatively use **partition projection** in Athena
# - Reduces metadata scanning and speeds up query planning
#
# ---
#
# ## 💡 Exam Hint
# Too many partitions → **Partition Projection / Index**

# %% [markdown]
# ## ❓ Question
# A data engineer needs to process real-time streaming data with time-based aggregations (up to 30-minute windows). The solution must be scalable, fault-tolerant, and require minimal operational management. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Stream Processing (Windowed Aggregations)
#
# ---
#
# ## 🛠️ Services
# - Amazon Kinesis Data Streams
# - Amazon Managed Service for Apache Flink
#
# ---
#
# ## ⚠️ Issue
# Need real-time windowed aggregations with high scalability and low ops.
#
# ---
#
# ## ✅ Solution
# - Use **Amazon Managed Service for Apache Flink**
# - Supports **time-window aggregations** (e.g., tumbling/sliding windows)
# - Fully managed, scalable, and fault-tolerant
#
# ---
#
# ## 💡 Exam Hint
# Streaming + window aggregation → **Flink**

# %% [markdown]
# ## ❓ Question
# A data engineer needs to upgrade multiple Amazon EBS gp2 volumes to gp3 to reduce cost and improve performance without downtime or data loss. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Storage Optimization (EBS)
#
# ---
#
# ## 🛠️ Services
# - Amazon EBS
#
# ---
#
# ## ⚠️ Issue
# Need seamless volume upgrade without interruption.
#
# ---
#
# ## ✅ Solution
# - Use **EBS Elastic Volumes**
# - Modify volume type from **gp2 → gp3**
# - No downtime, no data migration required
#
# ---
#
# ## 💡 Exam Hint
# EBS upgrade without downtime → **Elastic Volumes**

# %% [markdown]
# ## ❓ Question
# During migration from SQL Server on EC2 to Amazon RDS, the analytics team needs to export large joined datasets daily and store them in S3 as Parquet files. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Export & Transformation
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - Amazon S3
# - Amazon RDS / SQL Server
#
# ---
#
# ## ⚠️ Issue
# Need to extract, join, and convert large datasets to Parquet efficiently.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue ETL job**
# - Connect to SQL Server using **JDBC**
# - Perform joins and transformations
# - Write output in **Parquet format to S3**
#
# ---
#
# ## 💡 Exam Hint
# DB → transform → Parquet in S3 → **Glue ETL**

# %% [markdown]
# ## ❓ Question
# A data engineer using Amazon Redshift needs to detect and record query performance anomalies, such as missing statistics or skewed joins. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Monitoring & Query Optimization (Redshift)
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
# - Redshift Advisor
# - Amazon CloudWatch
#
# ---
#
# ## ⚠️ Issue
# Need automated detection of query performance issues.
#
# ---
#
# ## ✅ Solution
# - Use **Redshift Advisor**
# - Provides recommendations for:
#   - Missing statistics
#   - Skewed joins
#   - Distribution/sort key issues
# - Monitor via **CloudWatch** if needed
#
# ---
#
# ## 💡 Exam Hint
# Redshift performance recommendations → **Redshift Advisor** or **STL_EVENT_LOG_TABLE**

# %% [markdown]
# ## ❓ Question
# A data engineer ingests CSV files into S3. Analysts query only a few columns using Athena. How can performance be improved and cost reduced?
#
# ---
#
# ## 📌 Topic
# Query Optimization (Columnar Storage)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - Amazon Athena
# - AWS Glue
#
# ---
#
# ## ⚠️ Issue
# CSV format scans entire data → high cost and slow queries.
#
# ---
#
# ## ✅ Solution
# - Convert data to **columnar format (Parquet/ORC)**
# - Apply **compression (Snappy)**
# - Store in S3 for Athena queries
#
# ---
#
# ## 💡 Exam Hint
# Few columns queried → **Use Parquet (columnar format)**

# %% [markdown]
# ## ❓ Question
# A company stores HR data in a central S3 data lake across multiple regions. Each regional HR team should only access data for their own region. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Governance & Access Control
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - AWS Lake Formation
# - AWS IAM
#
# ---
#
# ## ⚠️ Issue
# Need fine-grained access so users only see region-specific data.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Lake Formation**
# - Apply **row-level or tag-based access control (LF-Tags)** by region
# - Restrict access so each team sees only its own region’s data
#
# ---
#
# ## 💡 Exam Hint
# Region-based access control → **Lake Formation**

# %% [markdown]
# ## ❓ Question
# A Step Functions workflow triggers EMR jobs that load data into Redshift, but the EMR jobs fail to start after deployment. What is the most likely issue and solution?
#
# ---
#
# ## 📌 Topic
# Permissions & Service Integration
#
# ---
#
# ## 🛠️ Services
# - AWS Step Functions
# - Amazon EMR
# - AWS IAM
#
# ---
#
# ## ⚠️ Issue
# EMR jobs are not starting → likely permission/configuration issue.
#
# ---
#
# ## ✅ Solution
# - Ensure **Step Functions IAM role** has permissions to:
#   - `elasticmapreduce:RunJobFlow`
#   - `elasticmapreduce:AddJobFlowSteps`
# - Verify **service role and instance profile** for EMR are correctly configured
#
# ---
#
# ## 💡 Exam Hint
# Service not starting in workflow → **Check IAM permissions**

# %% [markdown]
# ## ❓ Question
# An EC2 application currently stores temporary data. The company now needs to persist data even if instances are stopped or terminated. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Persistent Storage (EC2)
#
# ---
#
# ## 🛠️ Services
# - Amazon EC2
# - Amazon EBS
#
# ---
#
# ## ⚠️ Issue
# Instance store is ephemeral → data lost on stop/terminate.
#
# ---
#
# ## ✅ Solution
# - Use **Amazon EBS volumes** for persistent storage
# - Attach EBS to EC2 instance
# - Data persists independently of instance lifecycle
#
# ---
#
# ## 💡 Exam Hint
# EC2 + persistent storage → **EBS (not instance store)**

# %% [markdown]
# ## ❓ Question
# A data engineer currently uses Athena SQL-based ETL but now needs to run Spark analytics through Athena without managing EMR clusters. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Serverless Spark Processing
#
# ---
#
# ## 🛠️ Services
# - Amazon Athena
# - Athena for Apache Spark
#
# ---
#
# ## ⚠️ Issue
# Need to run Spark workloads without managing infrastructure.
#
# ---
#
# ## ✅ Solution
# - Use **Athena for Apache Spark**
# - Enables running Spark jobs in a **serverless environment**
# - No need to manage EMR clusters
#
# ---
#
# ## 💡 Exam Hint
# Spark without EMR → **Athena for Apache Spark**

# %% [markdown]
# ## ❓ Question
# A data engineer manages partitioned data in S3 and needs AWS Glue Data Catalog to update automatically with minimal delay so Athena can query new partitions immediately. What are the best solutions?
#
# ---
#
# ## 📌 Topic
# Metadata Management (Partition Updates)
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - Amazon Athena
# - Amazon S3
# - AWS SDK / API
#
# ---
#
# ## ⚠️ Issue
# Need near real-time partition availability (crawler can have delay).
#
# ---
#
# ## ✅ Solution (Better / Low Latency)
# - Use **Glue API (BatchCreatePartition / CreatePartition)**
# - Trigger via **Lambda on S3 event**
# - Adds partitions **instantly** to Glue Catalog
#
# ---
#
# ## ✅ Alternative
# - Use **Athena `ALTER TABLE ADD PARTITION`**
# - Or enable **Partition Projection** (no need to add partitions at all)
#
# ---
#
# ## ❌ Less Optimal
# - Glue Crawler → has delay and extra cost
#
# ---
#
# ## 💡 Exam Hint
# Real-time partitions → **API / Partition Projection**
# Scheduled/Batch → **Glue Crawler**

# %% [markdown]
# ## ❓ Question
# A data engineer needs to ingest data from third-party SaaS applications into an S3 data lake for Redshift analytics. The solution must be fully managed and low-maintenance. What is the best solution?
#
# ---
#
# ## 📌 Topic
# SaaS Data Ingestion (Managed Integration)
#
# ---
#
# ## 🛠️ Services
# - AWS AppFlow
# - Amazon S3
# - Amazon Redshift
#
# ---
#
# ## ⚠️ Issue
# Need to ingest data from SaaS apps without building custom pipelines.
#
# ---
#
# ## ✅ Solution
# - Use **AWS AppFlow**
# - Fully managed service to transfer data from SaaS → S3/Redshift
# - Supports scheduling, filtering, and transformation
#
# ---
#
# ## 💡 Exam Hint
# SaaS → AWS (managed) → **AppFlow**

# %% [markdown]
# ## ❓ Question
# A data engineer queries sales data in Athena, but some products are missing from aggregation results even though they exist in the table. What is the most likely issue and solution?
#
# ---
#
# ## 📌 Topic
# SQL Query Logic (Aggregation)
#
# ---
#
# ## 🛠️ Services
# - Amazon Athena
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Missing records during aggregation → likely due to incorrect filtering or grouping logic.
#
# ---
#
# ## ✅ Solution
# - Check query conditions (e.g., `WHERE` clause filtering out data unintentionally)
# - Ensure proper **GROUP BY columns**
# - Use **LEFT JOIN instead of INNER JOIN** if joins are involved
# - Verify **partition filters** are not excluding data
#
# ---
#
# ## 💡 Exam Hint
# Missing data in aggregation → **Check WHERE / JOIN / GROUP BY logic**

# %% [markdown]
# ## ❓ Question
# A data engineer needs to run a one-time query on Parquet data in S3, retrieving only one column, without setting up infrastructure like Glue or Athena. What is the best solution?
#
# ---
#
# ## 📌 Topic
# S3 Query-in-Place (Lightweight)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - S3 Select
#
# ---
#
# ## ⚠️ Issue
# Need quick, simple query without full analytics setup.
#
# ---
#
# ## ✅ Solution
# - Use **S3 Select**
# - Retrieve only required column from Parquet files
# - No need for Athena or Glue
#
# ---
#
# ## 💡 Exam Hint
# One-time + simple query on S3 → **S3 Select**

# %% [markdown]
# ## ❓ Question
# A data engineer uses materialized views in Amazon Redshift that must be refreshed on a recurring schedule. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Scheduling & Automation (Redshift)
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
# - Redshift Query Editor v2
#
# ---
#
# ## ⚠️ Issue
# Need recurring refresh of materialized views without complex setup.
#
# ---
#
# ## ✅ Solution
# - Use **Redshift Query Editor v2 scheduling**
# - Schedule `REFRESH MATERIALIZED VIEW` queries directly
# - No need for Lambda or external orchestration
#
# ---
#
# ## 💡 Exam Hint
# Simple Redshift scheduling → **Query Editor v2 (built-in scheduler)**

# %% [markdown]
# ## ❓ Question
# A data engineer needs to orchestrate a small pipeline with one Lambda function followed by one Glue job. What is the simplest solution?
#
# ---
#
# ## 📌 Topic
# Workflow Orchestration (Simple Pipeline)
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - AWS Lambda
# - AWS Glue Workflows / Triggers
#
# ---
#
# ## ⚠️ Issue
# Need simple sequential execution (Lambda → Glue) with minimal complexity.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue Workflow with triggers**
# - Trigger Lambda first, then trigger Glue job sequentially
#
# ---
#
# ## 💡 Exam Hint
# Simple pipeline → **Glue Workflows (not Step Functions)**

# %% [markdown]
# ## ❓ Question
# A company needs a centralized metadata catalog for multiple AWS data sources including RDS, Redshift, and semi-structured data (JSON/XML) in S3. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Metadata Management (Data Catalog)
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - AWS Glue Data Catalog
#
# ---
#
# ## ⚠️ Issue
# Need a unified metadata repository across multiple data sources.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue Data Catalog**
# - Store metadata for:
#   - RDS
#   - Redshift
#   - S3 (JSON/XML)
# - Acts as centralized schema repository
#
# ---
#
# ## 💡 Exam Hint
# Central metadata store → **Glue Data Catalog**

# %% [markdown]
# ## ❓ Question
# A DynamoDB table uses provisioned capacity with predictable traffic spikes every Monday morning. How can the company maintain performance while minimizing idle cost?
#
# ---
#
# ## 📌 Topic
# Cost Optimization (DynamoDB)
#
# ---
#
# ## 🛠️ Services
# - Amazon DynamoDB
# - DynamoDB Auto Scaling
#
# ---
#
# ## ⚠️ Issue
# Provisioned capacity leads to over-provisioning during idle times.
#
# ---
#
# ## ✅ Solution
# - Use **DynamoDB Auto Scaling**
# - Automatically scales read/write capacity based on demand
# - Handles predictable spikes efficiently
#
# ---
#
# ## 💡 Exam Hint
# Predictable spikes + cost optimization → **Auto Scaling (not on-demand always)**

# %% [markdown]
# ## ❓ Question
# A company is migrating Hadoop clusters and Hive metastore to AWS and needs a serverless, cost-effective solution to maintain the data catalog. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Metadata Management (Hive Metastore Replacement)
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - AWS Glue Data Catalog
#
# ---
#
# ## ⚠️ Issue
# Need serverless replacement for Hive metastore.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue Data Catalog**
# - Fully managed, serverless metadata store
# - Compatible with Hive metastore
#
# ---
#
# ## 💡 Exam Hint
# Hive metastore replacement → **Glue Data Catalog**

# %% [markdown]
# ## ❓ Question
# In an Amazon Redshift cluster, one node has >90% CPU utilization while others are underutilized, causing query queuing and performance issues. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Performance Optimization (Data Distribution)
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
#
# ---
#
# ## ⚠️ Issue
# Data skew → uneven distribution → one node overloaded.
#
# ---
#
# ## ✅ Solution
# - Choose proper **DISTKEY** to evenly distribute data
# - Use **EVEN distribution** if no clear key
# - Review **SORTKEY** and query patterns
#
# ---
#
# ## 💡 Exam Hint
# One node overloaded → **Data skew → fix DISTKEY**

# %% [markdown]
# ## ❓ Question
# A company stores IoT JSON data in S3 where schema changes over time. They need a catalog that automatically adapts to schema changes. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Schema Evolution & Metadata Management
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - AWS Glue Crawler
# - AWS Glue Data Catalog
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Schema changes frequently → manual updates are not feasible.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue Crawler**
# - Automatically detects **schema changes** in JSON data
# - Updates **Glue Data Catalog** dynamically
#
# ---
#
# ## 💡 Exam Hint
# Changing schema → **Glue Crawler (schema evolution)**

# %% [markdown]
# ## ❓ Question
# A company needs to log every write operation (uploads, deletes, modifications) in an S3 bucket and store logs in another S3 bucket. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Audit Logging (S3)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - AWS CloudTrail
#
# ---
#
# ## ⚠️ Issue
# Need to track all object-level operations.
#
# ---
#
# ## ✅ Solution
# - Enable **AWS CloudTrail Data Events** for S3
# - Configure logs to be delivered to another **S3 bucket**
# - Captures all object-level API operations
#
# ---
#
# ## 💡 Exam Hint
# Track S3 object operations → **CloudTrail Data Events**

# %% [markdown]
# ## ❓ Question
# A company uses EMR and Athena with metadata partially in Hive. They need a central metadata repository accessible by both systems. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Metadata Management (Central Catalog)
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - AWS Glue Data Catalog
# - Amazon EMR
# - Amazon Athena
#
# ---
#
# ## ⚠️ Issue
# Metadata is fragmented → need a unified catalog.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue Data Catalog** as central repository
# - Configure **EMR and Athena** to use Glue Data Catalog
# - Replaces Hive metastore
#
# ---
#
# ## 💡 Exam Hint
# Shared metadata across EMR + Athena → **Glue Data Catalog**

# %% [markdown]
# ## ❓ Question
# A company needs row-level and column-level access control across Athena, Redshift Spectrum, and EMR for shared datasets in an S3 data lake. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Fine-Grained Data Access Control
#
# ---
#
# ## 🛠️ Services
# - AWS Lake Formation
# - Amazon S3
# - Amazon Athena
# - Amazon Redshift Spectrum
# - Amazon EMR
#
# ---
#
# ## ⚠️ Issue
# Need consistent fine-grained access control across multiple analytics services.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Lake Formation**
# - Implement:
#   - **Row-level security**
#   - **Column-level security**
# - Apply centralized governance across all services
#
# ---
#
# ## 💡 Exam Hint
# Row + column level access → **Lake Formation**

# %% [markdown]
# ## ❓ Question
# A data engineer stores CSV files in S3 for Athena queries. As data grows, queries become slow. How can performance and cost be optimized?
#
# ---
#
# ## 📌 Topic
# Query Optimization (Athena)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - Amazon Athena
# - AWS Glue
#
# ---
#
# ## ⚠️ Issue
# CSV format → full scan → slow queries and high cost.
#
# ---
#
# ## ✅ Solution
# - Convert data to **Parquet (columnar format)**
# - Apply **partitioning** (e.g., by date or key)
# - Enable **compression (Snappy)**
#
# ---
#
# ## 💡 Exam Hint
# CSV slow in Athena → **Parquet + Partitioning**

# %% [markdown]
# ## ❓ Question
# A write-heavy Amazon RDS for MySQL database has high CPU utilization, slowing the application. How can CPU usage be reduced while maintaining performance and stability?
#
# ---
#
# ## 📌 Topic
# Performance Optimization (RDS)
#
# ---
#
# ## 🛠️ Services
# - Amazon RDS (MySQL)
# - RDS Performance Insights
# - RDS Scaling (Instance Resize)
# - RDS Read Replicas
#
# ---
#
# ## ⚠️ Issue
# High CPU utilization impacting application performance.
#
# ---
#
# ## ✅ Solution
# - Use **RDS Performance Insights** to identify CPU bottlenecks (queries, waits)
# - **Scale up instance (add compute)** for better CPU capacity
# - Add **Read Replicas** to offload read traffic
#
# ---
#
# ## 💡 Exam Hint
# High CPU → **Analyze (Performance Insights) + Scale compute + Read replicas**

# %% [markdown]
# ## ❓ Question
# A Redshift table with frequent updates/deletes and an interleaved sort key has growing disk usage and slower queries. How can space be reclaimed and sort performance restored?
#
# ---
#
# ## 📌 Topic
# Maintenance & Performance Optimization (Redshift)
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
#
# ---
#
# ## ⚠️ Issue
# Frequent updates/deletes → table bloat + unsorted data → degraded performance.
#
# ---
#
# ## ✅ Solution
# - Run **VACUUM REINDEX**
#   - Reclaims space
#   - Rebuilds interleaved sort keys
# - Optionally run **ANALYZE** to update statistics
#
# ---
#
# ## 💡 Exam Hint
# Interleaved sort key + bloat → **VACUUM REINDEX**

# %% [markdown]
# ## ❓ Question
# A company needs near real-time IoT ingestion with persistent nested JSON and sub-10 ms query latency, with minimal operational overhead. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Low-Latency NoSQL / Real-Time Analytics
#
# ---
#
# ## 🛠️ Services
# - Amazon DynamoDB
# - Amazon DynamoDB Streams (optional)
# - Amazon Kinesis (optional for ingestion)
#
# ---
#
# ## ⚠️ Issue
# Need millisecond latency + support for nested JSON + serverless.
#
# ---
#
# ## ✅ Solution
# - Use **Amazon DynamoDB**
# - Supports **nested JSON documents**
# - Provides **single-digit millisecond latency**
# - Fully managed (minimal ops)
#
# ---
#
# ## 💡 Exam Hint
# Sub-10 ms + JSON + serverless → **DynamoDB**

# %% [markdown]
# ## ❓ Question
# An S3 data lake contains PII. Multiple user groups need access, but each should only see specific PII columns based on their role. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Fine-Grained Access Control (Column-Level Security)
#
# ---
#
# ## 🛠️ Services
# - AWS Lake Formation
# - Amazon S3
# - Amazon Athena / Redshift Spectrum
#
# ---
#
# ## ⚠️ Issue
# Need column-level access control for sensitive (PII) data.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Lake Formation**
# - Apply **column-level security** based on roles
# - Restrict access to specific PII columns
#
# ---
#
# ## 💡 Exam Hint
# PII + column restriction → **Lake Formation**

# %% [markdown]
# ## ❓ Question
# Every 15 minutes, files from multiple sources (CSV/JSON/Parquet) arrive in S3. Data must be loaded into multiple Redshift tables and handle schema changes automatically. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Automated Ingestion & Schema Evolution
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - AWS Glue
# - AWS Glue Crawler
# - Amazon Redshift
#
# ---
#
# ## ⚠️ Issue
# Frequent ingestion + multiple formats + schema changes.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue Crawler** to detect schema changes automatically
# - Use **AWS Glue ETL jobs** to transform and load into Redshift
# - Schedule jobs every 15 minutes
#
# ---
#
# ## 💡 Exam Hint
# Schema changes + ingestion → **Glue Crawler + Glue ETL**

# %% [markdown]
# ## ❓ Question
# Athena queries petabyte-scale S3 data hourly for a BI app, but data updates only daily, causing high cost due to repeated scans. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Query Cost Optimization (Athena)
#
# ---
#
# ## 🛠️ Services
# - Amazon Athena
# - Amazon S3
# - Amazon Redshift (optional)
#
# ---
#
# ## ⚠️ Issue
# Repeated full scans of unchanged data → high cost.
#
# ---
#
# ## ✅ Solution
# - Use **Athena CTAS (CREATE TABLE AS SELECT)** or **materialized results**
# - Store precomputed results in S3
# - Query smaller, processed dataset instead of raw data
#
# ---
#
# ## 💡 Exam Hint
# Repeated queries on same data → **Precompute (CTAS / Materialized data)**

# %% [markdown]
# ## ❓ Question
# A Redshift cluster cannot be resized due to budget limits. Tables vary in size (some huge, some tiny). How can performance be improved without adding hardware?
#
# ---
#
# ## 📌 Topic
# Performance Optimization (Redshift Distribution)
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
#
# ---
#
# ## ⚠️ Issue
# Uneven table sizes → inefficient joins and data movement.
#
# ---
#
# ## ✅ Solution
# - Use appropriate **DISTSTYLE**:
#   - **KEY distribution** for large tables (based on join key)
#   - **ALL distribution** for small tables (replicate across nodes)
# - Reduces data shuffling and improves query performance
#
# ---
#
# ## 💡 Exam Hint
# Small vs large tables → **DISTSTYLE ALL + KEY optimization**

# %% [markdown]
# ## ❓ Question
# CSV files contain fields like Door_No, Street_Name, City, Zip_Code. The requirement is to create a single nested JSON-style column with these fields using minimal coding. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Transformation (Low-Code)
#
# ---
#
# ## 🛠️ Services
# - AWS Glue DataBrew
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Need to transform flat CSV into nested JSON with minimal coding effort.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue DataBrew**
# - Apply transformation to **combine columns into nested structure (JSON)**
# - Low-code, UI-based transformation
#
# ---
#
# ## 💡 Exam Hint
# Low-code transformation → **Glue DataBrew**

# %% [markdown]
# ## ❓ Question
# Sensitive call logs in S3 must be encrypted and accessible only by specific employees, with minimal operational overhead. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Security (Encryption + Access Control)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - AWS KMS
# - AWS IAM
#
# ---
#
# ## ⚠️ Issue
# Need secure encryption + restricted access with minimal management.
#
# ---
#
# ## ✅ Solution
# - Enable **S3 Server-Side Encryption with AWS KMS (SSE-KMS)**
# - Use **IAM policies + KMS key policies** to restrict access to specific users
# - Fully managed with minimal ops
#
# ---
#
# ## 💡 Exam Hint
# Encryption + fine access → **SSE-KMS + IAM**

# %% [markdown]
# ## ❓ Question
# Petabytes of data are stored in S3 Standard with unpredictable access patterns. The company wants to reduce cost while maintaining millisecond retrieval and minimal operational effort. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Storage Optimization (S3)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - S3 Intelligent-Tiering
#
# ---
#
# ## ⚠️ Issue
# Unpredictable access → hard to choose storage class manually.
#
# ---
#
# ## ✅ Solution
# - Use **S3 Intelligent-Tiering**
# - Automatically moves data between tiers based on access
# - Maintains **millisecond access** with no performance impact
# - Minimal operational overhead
#
# ---
#
# ## 💡 Exam Hint
# Unpredictable access → **S3 Intelligent-Tiering**

# %% [markdown]
# ## ❓ Question
# An AWS Glue job has hard-coded Redshift credentials. Security requires removing embedded secrets and securing access. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Security & Secrets Management
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - AWS Secrets Manager
# - AWS IAM
#
# ---
#
# ## ⚠️ Issue
# Hard-coded credentials → security risk.
#
# ---
#
# ## ✅ Solution
# - Store credentials in **AWS Secrets Manager**
# - Configure Glue job to **retrieve secrets securely**
# - Use **IAM roles** for access control
#
# ---
#
# ## 💡 Exam Hint
# Hard-coded credentials → **Secrets Manager**

# %% [markdown]
# ## ❓ Question
# A company manually creates and deletes a provisioned Redshift cluster each month for heavy analytics. They need a hands-off, cost-efficient solution. What is the best approach?
#
# ---
#
# ## 📌 Topic
# Serverless Data Warehousing
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift Serverless
#
# ---
#
# ## ⚠️ Issue
# Manual cluster management → operational overhead and inefficiency.
#
# ---
#
# ## ✅ Solution
# - Use **Amazon Redshift Serverless**
# - Automatically scales compute as needed
# - Pay only for usage → cost-efficient
# - No cluster management required
#
# ---
#
# ## 💡 Exam Hint
# Intermittent workloads → **Redshift Serverless**

# %% [markdown]
# ## ❓ Question
# A ~2 GB Excel (.xls) file lands daily in S3 with first/last name columns. The engineer needs to concatenate names and count distinct customers with minimal effort. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Low-Code Data Preparation & Analysis
#
# ---
#
# ## 🛠️ Services
# - AWS Glue DataBrew
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Need transformation + aggregation with minimal coding.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue DataBrew**
# - Import Excel file from S3
# - Create calculated column (concat first + last name)
# - Use built-in profiling to get **distinct count**
#
# ---
#
# ## 💡 Exam Hint
# Excel + minimal effort → **Glue DataBrew**

# %% [markdown]
# ## ❓ Question
# A company streams real-time data via Kinesis and needs near real-time analytics in Redshift Serverless, combining live and historical data with minimal operations. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Real-Time Analytics (Redshift)
#
# ---
#
# ## 🛠️ Services
# - Amazon Kinesis Data Streams
# - Amazon Redshift Serverless
# - Redshift Streaming Ingestion
#
# ---
#
# ## ⚠️ Issue
# Need to query live streaming data along with historical data.
#
# ---
#
# ## ✅ Solution
# - Use **Redshift Streaming Ingestion** from Kinesis
# - Query streaming + historical data together in Redshift
# - Fully managed, minimal ops
#
# ---
#
# ## 💡 Exam Hint
# Kinesis → Redshift real-time → **Streaming Ingestion**

# %% [markdown]
# ## ❓ Question
# A QuickSight dashboard querying Athena on S3 fails with “insufficient permissions.” What are the likely permission issues?
#
# ---
#
# ## 📌 Topic
# Access Control & Permissions
#
# ---
#
# ## 🛠️ Services
# - Amazon QuickSight
# - Amazon Athena
# - Amazon S3
# - AWS IAM
# - AWS Glue Data Catalog
#
# ---
#
# ## ⚠️ Issue
# QuickSight cannot access underlying data or metadata.
#
# ---
#
# ## ✅ Solution (Check Permissions)
# - **S3 Bucket Access**
#   - QuickSight role needs `s3:GetObject` and `s3:ListBucket`
#
# - **Athena Permissions**
#   - Access to query execution + results location (S3)
#
# - **Glue Data Catalog**
#   - Permissions to read tables (`glue:GetTable`, etc.)
#
# - **IAM Role (QuickSight)**
#   - Ensure correct role is attached and trusted
#
# ---
#
# ## 💡 Exam Hint
# QuickSight + Athena error → **Check S3 + Athena + Glue permissions**

# %% [markdown]
# ## ❓ Question
# A company has data across S3 (JSON/CSV), RDS SQL Server, DynamoDB, and Redshift. Data scientists need to query all sources using SQL-like syntax with minimal operations. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Federated Query / Unified Analytics
#
# ---
#
# ## 🛠️ Services
# - Amazon Athena
# - Athena Federated Query
# - AWS Lambda (connectors)
#
# ---
#
# ## ⚠️ Issue
# Multiple data sources → need unified querying without ETL.
#
# ---
#
# ## ✅ Solution
# - Use **Amazon Athena Federated Query**
# - Query across:
#   - S3
#   - RDS
#   - DynamoDB
#   - Redshift
# - No data movement, serverless
#
# ---
#
# ## 💡 Exam Hint
# Query multiple sources with SQL → **Athena Federated Query**

# %% [markdown]
# ## ❓ Question
# A SageMaker Studio user launching AWS Glue interactive sessions gets AccessDenied. How can permissions between SageMaker and Glue be fixed?
#
# ---
#
# ## 📌 Topic
# IAM Role Assumption (Cross-Service Access)
#
# ---
#
# ## 🛠️ Services
# - Amazon SageMaker
# - AWS Glue
# - AWS IAM
# - AWS STS
#
# ---
#
# ## ⚠️ Issue
# SageMaker cannot access Glue due to missing role assumption permissions.
#
# ---
#
# ## ✅ Solution
# - Use **STS AssumeRole**:
#   - Allow SageMaker execution role to **assume a Glue access role**
# - Update IAM:
#   - Add `sts:AssumeRole` permission to SageMaker role
#   - Configure **trust policy** on Glue role to trust SageMaker
# - Grant Glue permissions to assumed role
#
# ---
#
# ## 💡 Exam Hint
# Cross-service access → **STS AssumeRole**

# %% [markdown]
# ## ❓ Question
# A company extracts 1 TB daily from SAP, SQL Server, MongoDB, Kafka, and DynamoDB with evolving schemas. Data must be ingested into S3 within 15 minutes and schemas must be detected automatically. What is the best solution?
#
# ---
#
# ## 📌 Topic
# High-Throughput Ingestion & Schema Detection
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - AWS Glue Crawler
# - Amazon Kinesis / Kafka (MSK)
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Multiple sources + schema evolution + near real-time ingestion.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue streaming ETL** (or Kafka/MSK integration) for fast ingestion
# - Use **Glue Crawler** for automatic schema detection
# - Store data in **S3 data lake**
#
# ---
#
# ## 💡 Exam Hint
# High volume + schema change → **Glue (streaming) + Crawler**

# %% [markdown]
# ## ❓ Question
# Multiple apps share S3 datasets. One app needs PII, another should not. Data must be redacted dynamically without duplicating data. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Dynamic Data Masking
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - S3 Object Lambda
# - AWS Lambda
# - (Alternative) AWS Lake Formation
#
# ---
#
# ## ⚠️ Issue
# Need to transform/redact data dynamically at access time without storing multiple copies.
#
# ---
#
# ## ✅ Solution (Best Fit Here)
# - Use **S3 Object Lambda**
# - Attach a **Lambda function** to:
#   - Mask/remove PII fields dynamically
#   - Return transformed response to specific applications
# - No data duplication required
#
# ---
#
# ## ✅ Alternative
# - **AWS Lake Formation** for column-level access control (SQL-based tools)
#
# ---
#
# ## 💡 Exam Hint
# Dynamic transformation at read time → **S3 Object Lambda**
# Governance across analytics tools → **Lake Formation**

# %% [markdown]
# ## ❓ Question
# Users upload small (<100 MB) CSV files daily to S3. A simple, low-cost ETL process is required. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Lightweight ETL (Cost Optimization)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - AWS Lambda
# - AWS Glue Python Shell
#
# ---
#
# ## ⚠️ Issue
# Small files → need simple processing without heavy infrastructure.
#
# ---
#
# ## ✅ Solution (Better for ETL flexibility)
# - Use **AWS Glue Python Shell job**
#   - Supports lightweight Python-based ETL
#   - Cheaper than full Glue Spark jobs
# - Trigger via **S3 event or scheduler**
#
# ---
#
# ## ✅ Alternative
# - **AWS Lambda** (for very small/simple transformations)
#
# ---
#
# ## 💡 Exam Hint
# Light ETL + low cost → **Glue Python Shell**
# Very small/simple → **Lambda**

# %% [markdown]
# ## ❓ Question
# A Glue table needs new S3 partitions added without rescanning all data. What are the best approaches?
#
# ---
#
# ## 📌 Topic
# Partition Management (Glue / Athena)
#
# ---
#
# ## 🛠️ Services
# - AWS Glue Data Catalog
# - Amazon Athena
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Need efficient partition addition without full crawler run.
#
# ---
#
# ## ✅ Solution
# - **For few partitions (manual control):**
#   - Use `ALTER TABLE ADD PARTITION`
#
# - **For bulk partitions (auto discovery):**
#   - Use **MSCK REPAIR TABLE**
#   - Automatically discovers partitions from S3 folder structure
#
# - **For programmatic approach:**
#   - Use **Glue BatchCreatePartition API**
#
# ---
#
# ## 💡 Exam Hint
# - Few partitions → **ALTER TABLE**
# - Many partitions → **MSCK REPAIR TABLE**
# - Automation → **Glue API**

# %% [markdown]
# ## ❓ Question
# A company stores 10–15 TB of CSV data in S3 and queries it using Athena. They need faster queries and lower storage cost. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Storage & Query Optimization (Athena)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - Amazon Athena
# - AWS Glue
#
# ---
#
# ## ⚠️ Issue
# CSV → large scans → slow queries + high cost.
#
# ---
#
# ## ✅ Solution
# - Convert data to **Parquet (columnar format)**
# - Apply **compression (Snappy)**
# - Use **partitioning** (e.g., by date)
#
# ---
#
# ## 💡 Exam Hint
# Large CSV in Athena → **Parquet + Compression + Partitioning**

# %% [markdown]
# ## ❓ Question
# A company stores 10–15 TB of CSV data in S3 and queries it using Athena. They need faster queries and lower storage cost. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Storage & Query Optimization (Athena)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - Amazon Athena
# - AWS Glue
#
# ---
#
# ## ⚠️ Issue
# CSV → large scans → slow queries + high cost.
#
# ---
#
# ## ✅ Solution
# - Convert data to **Parquet (columnar format)**
# - Apply **compression (Snappy)**
# - Use **partitioning** (e.g., by date)
#
# ---
#
# ## 💡 Exam Hint
# Large CSV in Athena → **Parquet + Compression + Partitioning**

# %% [markdown]
# ## ❓ Question
# A company uses on-prem Apache Airflow with SQL-based data quality checks and wants to migrate to AWS with minimal refactoring. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Workflow Orchestration Migration
#
# ---
#
# ## 🛠️ Services
# - Amazon MWAA (Managed Workflows for Apache Airflow)
#
# ---
#
# ## ⚠️ Issue
# Need to migrate Airflow with minimal code changes.
#
# ---
#
# ## ✅ Solution
# - Use **Amazon MWAA**
# - Fully managed Airflow service
# - Reuse existing DAGs with minimal changes
#
# ---
#
# ## 💡 Exam Hint
# Airflow migration → **MWAA (lift-and-shift)**

# %% [markdown]
# ## ❓ Question
# Athena queries on S3 ALB logs are slow as the dataset grows and the table lacks partitions. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Query Optimization (Partitioning)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - Amazon Athena
# - AWS Glue
#
# ---
#
# ## ⚠️ Issue
# No partitioning → full table scan → slow queries.
#
# ---
#
# ## ✅ Solution
# - Partition data (e.g., by **year/month/day**)
# - Update table with partitions (Glue/Athena)
# - Optionally convert to **Parquet** for further optimization
#
# ---
#
# ## 💡 Exam Hint
# Athena slow + no partitions → **Add partitioning**

# %% [markdown]
# ## ❓ Question
# Need to trigger an AWS Glue workflow automatically after each successful S3 File Gateway upload. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Event-Driven Orchestration
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - AWS Glue
# - Amazon EventBridge (or S3 Event Notifications)
#
# ---
#
# ## ⚠️ Issue
# Need automatic trigger after file upload.
#
# ---
#
# ## ✅ Solution
# - Configure **S3 Event Notification / EventBridge rule**
# - Trigger **Glue Workflow (or Glue trigger)** on object creation
# - Fully automated pipeline
#
# ---
#
# ## 💡 Exam Hint
# S3 upload → trigger Glue → **EventBridge / S3 events**

# %% [markdown]
# ## ❓ Question
# A company using Aurora PostgreSQL and Redshift wants to archive old Redshift data to S3 but still query across Aurora, Redshift, and S3. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Federated & External Query
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift Spectrum
# - Amazon Aurora PostgreSQL
# - Amazon S3
# - Amazon Redshift
#
# ---
#
# ## ⚠️ Issue
# Need to query data across multiple sources without moving data back.
#
# ---
#
# ## ✅ Solution
# - Use **Redshift Spectrum** to query data in S3
# - Use **Redshift Federated Query** to query Aurora PostgreSQL
# - Combine results within Redshift
#
# ---
#
# ## 💡 Exam Hint
# Query S3 + Aurora + Redshift → **Spectrum + Federated Query**

# %% [markdown]
# ## ❓ Question
# Kinesis Data Streams receives IoT data keyed by facility ID, causing hot shards and throughput errors. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Streaming Optimization (Partitioning)
#
# ---
#
# ## 🛠️ Services
# - Amazon Kinesis Data Streams
#
# ---
#
# ## ⚠️ Issue
# Skewed partition key → hot shards → throttling.
#
# ---
#
# ## ✅ Solution
# - Use a **better partition key strategy**:
#   - Add randomness (e.g., `facilityID + random_suffix`)
# - Distribute records evenly across shards
# - Optionally increase shard count if needed
#
# ---
#
# ## 💡 Exam Hint
# Hot shard → **fix partition key (not just scaling)**

# %% [markdown]
# ## ❓ Question
# A data engineer wants to view Athena query performance and cost details for optimization. What is the best way to analyze and optimize queries?
#
# ---
#
# ## 📌 Topic
# Monitoring, Performance Tuning & Cost Optimization (Athena)
#
# ---
#
# ## 🛠️ Services
# - Amazon Athena
# - Amazon CloudWatch
# - AWS Cost Explorer
# - Amazon S3
#
# ---
#
# ## 🔍 What to Analyze
#
# ### 1. Athena Query Execution Details (MOST IMPORTANT)
# - Go to **Query History**
# - Check:
#   - **Data scanned (MB/GB)** → main cost driver
#   - **Execution time** → performance indicator
#   - **Query plan/stages** → bottlenecks
#
# 👉 Insight:
# - High data scanned = poor partitioning / wrong format
# - Slow queries = inefficient filters / joins
#
# ---
#
# ### 2. CloudWatch Metrics
# - Track:
#   - Query runtime trends
#   - Failed queries
#   - Throttling
#
# 👉 Insight:
# - Helps detect patterns (peak usage, failures)
#
# ---
#
# ### 3. Cost Analysis (Cost Explorer)
# - Filter by:
#   - Athena usage
# - Identify:
#   - Cost spikes
#   - Heavy queries/users
#
# 👉 Insight:
# - Athena cost = **$ per TB scanned**
#
# ---
#
# ## ⚡ Optimization Based on Analysis
#
# - Reduce scanned data:
#   - Use **partitioning**
#   - Convert to **Parquet/ORC**
# - Improve queries:
#   - Select only needed columns
#   - Add filters (WHERE clause)
# - Reuse results:
#   - Use **CTAS / materialized datasets**
#
# ---
#
# ## 💡 Key Concept
# 👉 Athena cost & performance = **Data Scanned**
#
# ---
#
# ## 🧠 Exam Shortcut
# If question says:
# - "optimize cost/performance in Athena"
# 👉 Think:
# - Query history
# - Reduce scanned data
# - Partition + Parquet
#
# --

# %% [markdown]
# ## ❓ Question
# An S3 data lake using Glue Data Catalog and Athena needs to enforce column-level access control based on user roles. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Fine-Grained Access Control
#
# ---
#
# ## 🛠️ Services
# - AWS Lake Formation
# - AWS Glue Data Catalog
# - Amazon Athena
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Need column-level security across analytics queries.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Lake Formation**
# - Define **column-level permissions** for roles
# - Enforce access through Athena using Glue Data Catalog
#
# ---
#
# ## 💡 Exam Hint
# Column-level restriction → **Lake Formation**

# %% [markdown]
# ## ❓ Question
# Glue ETL jobs reprocess all S3 files daily, but the requirement is to process only new or updated data since the last run. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Incremental Processing
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - Amazon S3
# - AWS Glue Job Bookmarks
#
# ---
#
# ## ⚠️ Issue
# Full reprocessing → inefficient and costly.
#
# ---
#
# ## ✅ Solution
# - Enable **Glue Job Bookmarks**
# - Tracks previously processed data
# - Processes only **new or modified files**
#
# ---
#
# ## 💡 Exam Hint
# Incremental ETL in Glue → **Job Bookmarks**

# %% [markdown]
# ## ❓ Question
# A company must collect and analyze VPC Flow Logs cheaply while keeping flexible query capabilities. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Cost-Effective Log Analytics
#
# ---
#
# ## 🛠️ Services
# - Amazon VPC Flow Logs
# - Amazon S3
# - Amazon Athena
# - AWS Glue Data Catalog
#
# ---
#
# ## ⚠️ Issue
# Need low-cost storage + flexible querying.
#
# ---
#
# ## ✅ Solution
# - Store **VPC Flow Logs in S3**
# - Use **Athena** for on-demand querying
# - Use **Glue Data Catalog** for schema
#
# ---
#
# ## 💡 Exam Hint
# Cheap + flexible queries → **S3 + Athena**

# %% [markdown]
# ## ❓ Question
# A small, rarely updated dimension table is repeatedly broadcast in Redshift joins, slowing queries. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Performance Optimization (Redshift Joins)
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
#
# ---
#
# ## ⚠️ Issue
# Repeated broadcasting of small table → inefficient joins.
#
# ---
#
# ## ✅ Solution
# - Use **DISTSTYLE ALL** on the small dimension table
# - Replicates table across all nodes
# - Eliminates broadcast during joins
#
# ---
#
# ## 💡 Exam Hint
# Small static table → **DISTSTYLE ALL**

# %% [markdown]
# ## ❓ Question
# In Amazon Redshift, retrieve all rows where `city_name` begins with 'San' or 'El'. What is the correct query?
#
# ---
#
# ## 📌 Topic
# SQL Pattern Matching
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
#
# ---
#
# ## ⚠️ Issue
# Filter rows based on multiple string prefixes.
#
# ---
#
# ## ✅ Solution
# ```sql
# SELECT *
# FROM table_name
# WHERE city_name LIKE 'San%'
#    OR city_name LIKE 'El%';

# %% [markdown]
# ## ❓ Question
# AWS DMS replication from PostgreSQL to Redshift shows high CDC latency. How can you confirm if the source database is the bottleneck?
#
# ---
#
# ## 📌 Topic
# Monitoring & Troubleshooting (DMS)
#
# ---
#
# ## 🛠️ Services
# - AWS DMS
# - Amazon CloudWatch
# - PostgreSQL
#
# ---
#
# ## ⚠️ Issue
# High CDC latency → need to identify whether source is slow.
#
# ---
#
# ## ✅ Solution
# - Check **DMS CloudWatch metrics**:
#   - **CDCLatencySource** → delay from source
#   - **CDCLatencyTarget** → delay at target
#
# 👉 Interpretation:
# - High **CDCLatencySource** → source DB is bottleneck
# - High **CDCLatencyTarget** → target (Redshift) is bottleneck
#
# ---
#
# ## 💡 Exam Hint
# DMS latency debugging → **CDCLatencySource vs Target**

# %% [markdown]
# ## ❓ Question
# IoT sensors send 100 KB every 10 seconds, and data must reach S3 within 30 seconds latency. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Streaming Ingestion (Low Latency vs Managed)
#
# ---
#
# ## 🛠️ Services
# - Amazon Kinesis Data Streams
# - Kinesis Client Library (KCL)
# - Amazon S3
# - (Alternative) Kinesis Data Firehose
#
# ---
#
# ## ⚠️ Issue
# Need **<30 sec latency** → Firehose buffering may be too slow.
#
# ---
#
# ## ✅ Best Solution
# - Use **Kinesis Data Streams + KCL consumer**
# - Consumer writes directly to **S3**
# - Achieves **near real-time (seconds-level latency)**
#
# ---
#
# ## ⚠️ Why NOT Firehose (in this case)?
# - Firehose buffering = typically **≥ 60 seconds**
# - May violate 30-second SLA
#
# ---
#
# ## 💡 Exam Insight
# - **Ultra low latency (<30s)** → Streams + KCL
# - **Managed, simple (latency OK ~60s)** → Firehose
#
# ---
#
# ## 🧠 Exam Trap
# If strict latency is mentioned → avoid Firehose
# 👉 Choose **Streams + custom consumer (KCL)**

# %% [markdown]
# ## ❓ Question
# Need daily 300 GB ETL and a one-time TB-scale historical transformation on S3, all orchestrated by MWAA. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Scalable ETL + Orchestration
#
# ---
#
# ## 🛠️ Services
# - Amazon MWAA (Airflow)
# - AWS Glue
# - Amazon EMR (optional)
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Mixed workloads:
# - Daily moderate ETL
# - One-time large-scale processing
#
# ---
#
# ## ✅ Solution
# - Use **MWAA** to orchestrate pipelines
# - Use:
#   - **AWS Glue** for daily ETL (serverless, cost-effective)
#   - **Amazon EMR** for one-time TB-scale transformation (high performance)
#
# ---
#
# ## 💡 Exam Hint
# - Orchestration → **MWAA**
# - Daily ETL → **Glue**
# - Large one-time → **EMR**

# %% [markdown]
# ## ❓ Question
# Glue ETL on customer orders must enforce business-specific data validation rules. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Quality & Validation
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - AWS Glue Data Quality
#
# ---
#
# ## ⚠️ Issue
# Need to enforce custom validation rules during ETL.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue Data Quality**
# - Define **data quality rulesets** (e.g., completeness, uniqueness, custom rules)
# - Validate data as part of Glue ETL job
#
# ---
#
# ## 💡 Exam Hint
# Data validation in Glue → **Glue Data Quality**

# %% [markdown]
# ## ❓ Question
# An insurance company stores gzip-compressed transaction data and needs occasional, low-cost queries. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Ad-hoc Query (Cost Optimization)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - Amazon Athena
#
# ---
#
# ## ⚠️ Issue
# Need infrequent querying → avoid provisioning infrastructure.
#
# ---
#
# ## ✅ Solution
# - Use **Amazon Athena**
# - Query data directly from S3 (supports gzip)
# - Pay-per-query → cost-effective for occasional use
#
# ---
#
# ## 💡 Exam Hint
# Occasional queries → **Athena (serverless, pay-per-use)**

# %% [markdown]
# ## ❓ Question
# A Redshift stored procedure must run automatically every day with minimal setup. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Scheduling (Redshift)
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
# - Redshift Query Editor v2
#
# ---
#
# ## ⚠️ Issue
# Need simple scheduling without external orchestration.
#
# ---
#
# ## ✅ Solution
# - Use **Redshift Query Editor v2 scheduling**
# - Schedule execution of stored procedure
#
# ---
#
# ## 💡 Exam Hint
# Simple Redshift scheduling → **Query Editor v2**

# %% [markdown]
# ## ❓ Question
# Clickstream data lands in S3 via Firehose. Need daily QuickSight dashboards that scale cost-effectively. What is the best solution?
#
# ---
#
# ## 📌 Topic
# BI Optimization (Cost & Performance)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - Amazon Athena
# - Amazon QuickSight (SPICE)
#
# ---
#
# ## ⚠️ Issue
# Direct querying large S3 data → slow & expensive dashboards.
#
# ---
#
# ## ✅ Solution
# - Use **Athena** to query S3 data
# - Import data into **QuickSight SPICE**
# - Schedule **daily refresh**
#
# ---
#
# ## 💡 Exam Hint
# QuickSight cost optimization → **SPICE (in-memory)**

# %% [markdown]
# ## ❓ Question
# An engineer needs portable orchestration across on-prem and AWS using open-source technology. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Workflow Orchestration (Hybrid / Open Source)
#
# ---
#
# ## 🛠️ Services
# - Apache Airflow
# - Amazon MWAA (optional managed option)
#
# ---
#
# ## ⚠️ Issue
# Need portability across environments → avoid vendor lock-in.
#
# ---
#
# ## ✅ Solution
# - Use **Apache Airflow**
# - Deploy on-prem and on AWS
# - Same DAGs work across environments
#
# ---
#
# ## 💡 Exam Hint
# Portable + open-source orchestration → **Airflow**

# %% [markdown]
# ## ❓ Question
# A gaming company needs a globally distributed NoSQL database with sub-10 ms latency for OLTP workloads. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Global Low-Latency Databases
#
# ---
#
# ## 🛠️ Services
# - Amazon DynamoDB
# - DynamoDB Global Tables
#
# ---
#
# ## ⚠️ Issue
# Need global distribution + millisecond latency.
#
# ---
#
# ## ✅ Solution
# - Use **DynamoDB Global Tables**
# - Provides **multi-region replication**
# - Delivers **single-digit millisecond latency**
#
# ---
#
# ## 💡 Exam Hint
# Global + NoSQL + low latency → **DynamoDB Global Tables**

# %% [markdown]
# ## ❓ Question
# An EventBridge rule invoking a Lambda function fails with AccessDeniedException. What is the best fix?
#
# ---
#
# ## 📌 Topic
# IAM & Event-Driven Permissions
#
# ---
#
# ## 🛠️ Services
# - Amazon EventBridge
# - AWS Lambda
# - AWS IAM
#
# ---
#
# ## ⚠️ Issue
# EventBridge does not have permission to invoke Lambda.
#
# ---
#
# ## ✅ Solution
# - Add **Lambda resource-based policy**:
#   - Allow **EventBridge** to invoke the function
# - Example:
#   ```bash
#   aws lambda add-permission \
#     --function-name my-function \
#     --statement-id eventbridge \
#     --action "lambda:InvokeFunction" \
#     --principal events.amazonaws.com \
#     --source-arn <eventbridge-rule-arn>

# %% [markdown]
# ## ❓ Question
# A company must comply with dual-layer encryption requirements for S3 data using AWS-native capabilities. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Security (Encryption)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - AWS KMS
#
# ---
#
# ## ⚠️ Issue
# Need two layers of encryption using native AWS features.
#
# ---
#
# ## ✅ Solution
# - Use **SSE-KMS with DSSE (Dual-layer Server-Side Encryption)**
# - Applies **two independent encryption layers** using AWS KMS
#
# ---
#
# ## 💡 Exam Hint
# Dual-layer encryption → **S3 DSSE-KMS**

# %% [markdown]
# ## ❓ Question
# Athena queries are delayed and queued due to limited concurrent query capacity. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Concurrency & Performance Optimization (Athena)
#
# ---
#
# ## 🛠️ Services
# - Amazon Athena
# - Workgroups
#
# ---
#
# ## ⚠️ Issue
# Limited concurrency → queries queue up → delays.
#
# ---
#
# ## ✅ Solution
# - Use **Athena Workgroups**
# - Split workloads across multiple workgroups
# - Isolate queries and improve concurrency
#
# ---
#
# ## 💡 Exam Hint
# Athena concurrency issue → **Use multiple Workgroups**

# %% [markdown]
# ## ❓ Question
# A Glue job with bookmarks still reprocesses old S3 files each run. What is the key fix?
#
# ---
#
# ## 📌 Topic
# Glue Job Bookmarks (State Management)
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
#
# ---
#
# ## ⚠️ Root Cause (MOST COMMON)
# Bookmark state is **not being saved**.
#
# ---
#
# ## ✅ Critical Fix
# - Add **`job.commit()`** at the end of the Glue script
#
# ```python
# job.commit()

# %% [markdown]
# ## ❓ Question
# A retail company needs near real-time replication from on-prem MySQL to Redshift using Direct Connect. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Replication (CDC)
#
# ---
#
# ## 🛠️ Services
# - AWS Database Migration Service (DMS)
# - Amazon Redshift
# - AWS Direct Connect
#
# ---
#
# ## ⚠️ Issue
# Need continuous, low-latency replication from on-prem to Redshift.
#
# ---
#
# ## ✅ Solution
# - Use **AWS DMS with CDC (Change Data Capture)**
# - Source: On-prem MySQL
# - Target: Redshift
# - Use **Direct Connect** for low-latency, private connectivity
#
# ---
#
# ## 💡 Exam Hint
# Near real-time DB replication → **DMS + CDC**

# %% [markdown]
# ## ❓ Question
# Data migration is required from RDS PostgreSQL in Account A (eu-east-1) to Redshift in Account B (eu-west-1). What is the best solution?
#
# ---
#
# ## 📌 Topic
# Cross-Account + Cross-Region Migration
#
# ---
#
# ## 🛠️ Services
# - AWS DMS
# - Amazon RDS (PostgreSQL)
# - Amazon Redshift
# - Amazon S3 (staging)
#
# ---
#
# ## ⚠️ Issue
# Cross-account + cross-region migration.
#
# ---
#
# ## ✅ Solution
# - Use **AWS DMS**:
#   - Source: RDS PostgreSQL (Account A)
#   - Target: Redshift (Account B)
# - Use **S3 as intermediate staging** if required
# - Configure **IAM roles & networking (VPC peering / endpoints)**
#
# ---
#
# ## 💡 Exam Hint
# Cross-account DB migration → **DMS**

# %% [markdown]
# ## ❓ Question
# Multiple S3 paths are loaded into Redshift using separate COPY commands, causing slow ingestion. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Redshift Load Optimization
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Multiple COPY commands → sequential loading → slow performance.
#
# ---
#
# ## ✅ Solution
# - Use a **single COPY command with multiple files/paths**
# - Leverage **parallel loading** from S3
# - Use **manifest file** if needed
#
# ---
#
# ## 💡 Exam Hint
# Slow COPY → **Use single COPY with multiple files (parallelism)**

# %% [markdown]
# ## ❓ Question
# Need to convert CSV → JSON and store as Parquet in S3 with minimal coding. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Streaming / Low-Code Transformation
#
# ---
#
# ## 🛠️ Services
# - Amazon Kinesis Data Firehose
# - AWS Lambda
# - Amazon S3
#
# ---
#
# ## ⚠️ Clarification
# Using **Kinesis Data Firehose alone is NOT enough**:
# - Firehose supports:
#   - Format conversion → **JSON → Parquet**
# - But **CSV → JSON requires transformation**
#
# ---
#
# ## ✅ Best Solution (Using Firehose)
# - Use **Kinesis Data Firehose**
# - Enable:
#   - **Lambda transformation** → convert CSV → JSON
#   - **Firehose data format conversion** → JSON → Parquet
# - Deliver to **S3**
#
# ---
#
# ## ⚠️ When to prefer Glue instead?
# - Batch files already in S3
# - No streaming required
#
# ---
#
# ## 💡 Exam Insight
# - CSV → JSON → Parquet (streaming) → **Firehose + Lambda**
# - Batch + low-code → **Glue Studio**

# %% [markdown]
# ## ❓ Question
# An AWS Transfer Family server must enforce TLS 1.2 or higher for compliance. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Security (Protocol Enforcement)
#
# ---
#
# ## 🛠️ Services
# - AWS Transfer Family
# - AWS Security Policy
#
# ---
#
# ## ⚠️ Issue
# Need to enforce minimum TLS version.
#
# ---
#
# ## ✅ Solution
# - Configure **Transfer Family security policy**
# - Select a policy that enforces **TLS 1.2 or higher** (e.g., modern security policy)
#
# ---
#
# ## 💡 Exam Hint
# TLS enforcement → **Security Policy (Transfer Family)**

# %% [markdown]
# ## ❓ Question
# A banking company’s Kinesis Data Streams pipeline produces duplicate records during network retries. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Idempotency & Deduplication (Streaming)
#
# ---
#
# ## 🛠️ Services
# - Amazon Kinesis Data Streams
# - AWS Lambda / Consumers
#
# ---
#
# ## ⚠️ Issue
# Retries → duplicate records → no built-in dedup in Kinesis Streams.
#
# ---
#
# ## ✅ Solution
# - Implement **idempotent processing**:
#   - Add **unique record IDs (primary key / event ID)**
#   - Deduplicate at consumer side
# - Store processed IDs (e.g., DynamoDB) to avoid reprocessing
#
# ---
#
# ## ⚠️ Important Note
# - Kinesis Data Streams = **at-least-once delivery**
# - Duplicates are expected → must handle downstream
#
# ---
#
# ## 💡 Exam Hint
# Duplicates in Kinesis → **Idempotent consumer (not service fix)**

# %% [markdown]
# ## ❓ Question
# Log files in S3 were accidentally deleted. A low-maintenance prevention mechanism is required. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Protection (S3)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - S3 Versioning
# - S3 Object Lock
#
# ---
#
# ## ⚠️ Issue
# Accidental deletion → need protection with minimal ops.
#
# ---
#
# ## ✅ Solution
# - Enable **S3 Versioning**
#   - Allows recovery of deleted objects
# - Optionally enable **S3 Object Lock (WORM)** for stronger protection
#
# ---
#
# ## 💡 Exam Hint
# Accidental delete → **Versioning**
# Strict protection → **Object Lock**

# %% [markdown]
# ## ❓ Question
# A telecom company must detect real-time drops in Aurora network usage with the lowest possible latency. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Real-Time Monitoring & Alerting
#
# ---
#
# ## 🛠️ Services
# - Amazon CloudWatch
# - Amazon Aurora
#
# ---
#
# ## ⚠️ Issue
# Need immediate detection (low latency) of metric changes.
#
# ---
#
# ## ✅ Solution
# - Use **CloudWatch metrics (Aurora)**
# - Create **CloudWatch Alarms** on network metrics (e.g., NetworkReceiveThroughput)
# - Trigger alerts instantly (SNS/Lambda)
#
# ---
#
# ## 💡 Exam Hint
# Real-time monitoring → **CloudWatch Alarms**

# %% [markdown]
# ## ❓ Question
# A data engineer must clean terabytes of raw data in S3 and load it into Redshift for analytics with minimal ETL complexity and management. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Serverless Data Transformation
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
# - Redshift Spectrum
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Large-scale data + minimal ETL → avoid heavy pipelines.
#
# ---
#
# ## ✅ Solution
# - Use **Redshift Spectrum** to query and transform data directly in S3
# - Use **CTAS (CREATE TABLE AS SELECT)** in Redshift to:
#   - Clean/transform data
#   - Load into Redshift tables
#
# ---
#
# ## 💡 Exam Hint
# Minimal ETL + S3 → **Spectrum + CTAS**

# %% [markdown]
# ## ❓ Question
# A VPC-enabled Lambda transfers files from on-prem SFTP to S3 but times out during upload. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Networking (Lambda + S3 Access)
#
# ---
#
# ## 🛠️ Services
# - AWS Lambda
# - Amazon S3
# - VPC Endpoints (Gateway Endpoint for S3)
# - NAT Gateway (alternative)
#
# ---
#
# ## ⚠️ Issue
# Lambda in VPC cannot reach S3 → no internet access → timeout.
#
# ---
#
# ## ✅ Best Solution
# - Create **S3 Gateway VPC Endpoint**
# - Update route tables to allow private S3 access
# - No internet/NAT required → faster + cheaper
#
# ---
#
# ## ⚠️ Alternative (less optimal)
# - Use **NAT Gateway** for internet access (costly)
#
# ---
#
# ## 💡 Exam Hint
# Lambda in VPC + S3 timeout → **Add S3 VPC Endpoint**

# %% [markdown]
# ## ❓ Question
# A company reads inconsistent customer data from multiple RDS databases and needs to link duplicate records with minimal setup. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Entity Resolution / Record Matching
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - AWS Glue ML Transform (FindMatches)
#
# ---
#
# ## ⚠️ Issue
# Duplicate/inconsistent records → need intelligent matching.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue ML Transform – FindMatches**
# - Automatically identifies and links duplicate records
# - Minimal manual rule creation
#
# ---
#
# ## 💡 Exam Hint
# Duplicate record matching → **Glue FindMatches (ML)**

# %% [markdown]
# ## ❓ Question
# SQS messages expire during application downtime, causing data loss. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Message Durability & Retention
#
# ---
#
# ## 🛠️ Services
# - Amazon SQS
#
# ---
#
# ## ⚠️ Issue
# Messages expire before being processed.
#
# ---
#
# ## ✅ Solution
# - Increase **SQS message retention period** (up to 14 days)
# - Ensure messages persist during downtime
#
# ---
#
# ## ⚠️ Additional Improvement
# - Configure **Dead Letter Queue (DLQ)** for failed processing
#
# ---
#
# ## 💡 Exam Hint
# Message expiry → **Increase retention period**

# %% [markdown]
# ## ❓ Question
# A company streams time-series data to MSK, Keyspaces, and OpenSearch and needs near real-time dashboards. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Real-Time Analytics & Visualization
#
# ---
#
# ## 🛠️ Services
# - Amazon OpenSearch Service
# - OpenSearch Dashboards
# - Amazon MSK
# - Amazon Keyspaces
#
# ---
#
# ## ⚠️ Issue
# Need near real-time visualization of streaming data.
#
# ---
#
# ## ✅ Solution
# - Use **Amazon OpenSearch + OpenSearch Dashboards**
# - Ingest streaming data into OpenSearch
# - Build **real-time dashboards**
#
# ---
#
# ## 💡 Exam Hint
# Real-time dashboards → **OpenSearch Dashboards**

# %% [markdown]
# ## ❓ Question
# A media company must transform millions of Kinesis Data Streams events and ingest them into OpenSearch in near real time. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Streaming Transformation & Delivery
#
# ---
#
# ## 🛠️ Services
# - Amazon Kinesis Data Streams
# - AWS Lambda
# - Amazon OpenSearch Service
#
# ---
#
# ## ⚠️ Issue
# High-throughput streaming + transformation + near real-time indexing.
#
# ---
#
# ## ✅ Solution
# - Use **Lambda as a Kinesis consumer**
# - Perform transformations in Lambda
# - Send data to **OpenSearch**
#
# ---
#
# ## ⚠️ Alternative (better managed)
# - Use **Kinesis Data Firehose**
#   - Built-in OpenSearch delivery
#   - Optional Lambda transformation
#
# ---
#
# ## 💡 Exam Hint
# Kinesis → OpenSearch → **Firehose (managed) OR Lambda (custom)**

# %% [markdown]
# ## ❓ Question
# A company must restrict users from viewing rows for customers in Canada using Lake Formation. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Fine-Grained Access Control (Row-Level)
#
# ---
#
# ## 🛠️ Services
# - AWS Lake Formation
# - Amazon Athena / Redshift Spectrum
#
# ---
#
# ## ⚠️ Issue
# Need to restrict access to specific rows based on condition.
#
# ---
#
# ## ✅ Solution
# - Use **Lake Formation row-level security (Data Filters)**
# - Apply filter:
#   ```sql
#   country != 'Canada'

# %% [markdown]
# ## ❓ Question
# A company wants users to authenticate to Redshift Query Editor using Okta or Azure AD. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Federated Authentication
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
# - AWS IAM Identity Center (SSO)
# - Okta / Azure AD (IdP)
#
# ---
#
# ## ⚠️ Issue
# Need external identity provider authentication.
#
# ---
#
# ## ✅ Solution
# - Use **IAM Identity Center (AWS SSO)**
# - Integrate with **Okta / Azure AD (SAML 2.0 IdP)**
# - Enable access to **Redshift Query Editor**
#
# ---
#
# ## 💡 Exam Hint
# External IdP → **IAM Identity Center (SSO + SAML)**

# %% [markdown]
# ## ❓ Question
# A Spark ETL job on EMR is CPU-bound with low memory usage. The company wants to reduce cost. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Cost Optimization (EMR Instance Selection)
#
# ---
#
# ## 🛠️ Services
# - Amazon EMR
# - Amazon EC2
#
# ---
#
# ## ⚠️ Issue
# CPU-heavy workload → overpaying for memory.
#
# ---
#
# ## ✅ Solution
# - Use **compute-optimized instances (C family, e.g., C6g/C5)**
# - Avoid memory-heavy instances (R family)
#
# ---
#
# ## ⚡ Optimization Tip
# - Prefer **Graviton (C6g)** for better price-performance
#
# ---
#
# ## 💡 Exam Hint
# CPU-bound → **Compute-optimized (C instances)**

# %% [markdown]
# ## ❓ Question
# A Lambda function tries to read an S3 object encrypted with KMS. The IAM role has S3 access, but the read fails. What is the issue and fix?
#
# ---
#
# ## 📌 Topic
# KMS Permissions
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - AWS Lambda
# - AWS KMS
# - AWS IAM
#
# ---
#
# ## ⚠️ Issue
# S3 access ≠ KMS decrypt permission.
#
# ---
#
# ## ✅ Solution
# - Grant **KMS permissions** to Lambda role:
#   - `kms:Decrypt`
# - Update **KMS key policy** to allow Lambda role
#
# ---
#
# ## 💡 Exam Hint
# S3 + KMS failure → **Missing kms:Decrypt**

# %% [markdown]
# ## ❓ Question
# A data engineer must modify data quality rules across 1,000 AWS Glue Data Catalog tables with minimal operational overhead and no manual updates per table. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Scalable Data Quality Management
#
# ---
#
# ## 🛠️ Services
# - AWS Glue Data Quality
# - AWS Glue Data Catalog
#
# ---
#
# ## ⚠️ Issue
# Updating rules individually → high operational overhead.
#
# ---
#
# ## ✅ Solution
# - Use **Glue Data Quality rulesets**
# - Create a **central reusable ruleset**
# - Apply ruleset across multiple tables programmatically
#
# ---
#
# ## ⚡ Optimization
# - Automate using **Glue APIs / scripts** to attach rulesets to all tables
#
# ---
#
# ## 💡 Exam Hint
# Bulk rule updates → **Reusable rulesets (Glue Data Quality)**

# %% [markdown]
# ## ❓ Question
# A Redshift table uses a **compound sort key**: (Region_ID, Department_ID, Role_ID). Which query patterns benefit the most?
#
# ---
#
# ## 📌 Topic
# Sort Key Optimization (Redshift)
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
#
# ---
#
# ## ⚠️ Concept
# Compound sort keys are **left-prefix optimized**.
#
# ---
#
# ## ✅ Best Performing Queries
# Queries that filter using:
# - `Region_ID`
# - `Region_ID + Department_ID`
# - `Region_ID + Department_ID + Role_ID`
#
# ### Example (BEST)
# ```sql
# WHERE Region_ID = 1

# %% [markdown]
# ## ❓ Question
# Millions of small (1 KB) JSON files in S3 are processed by Glue and loaded into Redshift. Job duration increases due to the small file problem. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Small File Optimization
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - Amazon S3
# - Amazon Redshift
#
# ---
#
# ## ⚠️ Issue
# Too many small files → high overhead → slow processing.
#
# ---
#
# ## ✅ Solution
# - **Compact small files into larger files** before/within Glue job
# - Use:
#   - Glue **coalesce / repartition**
# - Output optimized **larger Parquet files**
#
# ---
#
# ## ⚡ Additional Optimization
# - Target file size: ~128 MB – 1 GB
# - Improves:
#   - Glue performance
#   - Redshift COPY efficiency
#
# ---
#
# ## 💡 Exam Hint
# Small file problem → **Combine files (coalesce/repartition)**

# %% [markdown]
# ## ❓ Question
# A company uses Kinesis Data Streams for real-time logs and wants to ingest into Redshift for immediate querying and enrichment with minimal management. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Streaming Ingestion (Low Ops)
#
# ---
#
# ## 🛠️ Services
# - Amazon Kinesis Data Streams
# - Amazon Kinesis Data Firehose
# - Amazon Redshift
#
# ---
#
# ## ⚠️ Issue
# Need near real-time ingestion + minimal operational effort.
#
# ---
#
# ## ✅ Solution
# - Use **Kinesis Data Firehose**
#   - Source: Kinesis Data Streams
#   - Destination: Redshift
# - Optional:
#   - Lambda transformation for enrichment
#
# ---
#
# ## 💡 Exam Hint
# Kinesis → Redshift (low ops) → **Firehose**

# %%
## ❓ Question
A company uses Kinesis Data Streams for real-time logs and wants to ingest into Redshift for immediate querying and enrichment with minimal management. What is the best solution?

---

## 📌 Topic
Streaming Ingestion (Low Ops)

---

## 🛠️ Services
- Amazon Kinesis Data Streams
- Amazon Kinesis Data Firehose
- Amazon Redshift

---

## ⚠️ Issue
Need near real-time ingestion + minimal operational effort.

---

## ✅ Solution
- Use **Kinesis Data Firehose**
  - Source: Kinesis Data Streams
  - Destination: Redshift
- Optional:
  - Lambda transformation for enrichment

---

## 💡 Exam Hint
Kinesis → Redshift (low ops) → **Firehose**

# %%
## ❓ Question
A company uses Kinesis Data Streams for real-time logs and wants to ingest into Redshift for immediate querying and enrichment with minimal management. What is the best solution?

---

## 📌 Topic
Streaming Ingestion (Low Ops)

---

## 🛠️ Services
- Amazon Kinesis Data Streams
- Amazon Kinesis Data Firehose
- Amazon Redshift

---

## ⚠️ Issue
Need near real-time ingestion + minimal operational effort.

---

## ✅ Solution
- Use **Kinesis Data Firehose**
  - Source: Kinesis Data Streams
  - Destination: Redshift
- Optional:
  - Lambda transformation for enrichment

---

## 💡 Exam Hint
Kinesis → Redshift (low ops) → **Firehose**

# %% [markdown]
# ## ❓ Question
# An on-prem Oracle data warehouse (tables <50 GB, nightly refresh 1–2 AM) must land in S3 and stay in sync with daily incremental changes, ready for BI queries by 10 AM–8 PM. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Batch + Incremental Sync (Hybrid Ingestion)
#
# ---
#
# ## 🛠️ Services
# - AWS DMS
# - Amazon S3
# - AWS Glue Data Catalog / Athena (for BI)
#
# ---
#
# ## ⚠️ Requirements Breakdown
# - Initial full load (nightly window)
# - Continuous incremental updates (CDC)
# - Data available in S3 for querying
#
# ---
#
# ## ✅ Solution
# - Use **AWS DMS**
#   - Perform **full load** during nightly window
#   - Enable **CDC (Change Data Capture)** for incremental sync
#   - Target: **Amazon S3** (Parquet recommended)
#
# ---
#
# ## ⚡ Optimization
# - Store in **Parquet + partitioned format**
# - Use **Glue Catalog + Athena** for BI queries
#
# ---
#
# ## 💡 Exam Hint
# Full load + incremental sync → **DMS (Full Load + CDC)**

# %% [markdown]
# ## ❓ Question
# A team uses S3 (Parquet) + Athena. Source is on-prem Oracle (~70 tables) with occasional changes. Data must be ingested daily with least effort. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Low-Operational Batch Ingestion
#
# ---
#
# ## 🛠️ Services
# - AWS DataSync
# - AWS Glue / Athena
# - Amazon S3
#
# ---
#
# ## ⚠️ Issue
# Data changes occasionally → no need for continuous CDC → keep ops minimal.
#
# ---
#
# ## ✅ Best Solution
# - Use **AWS DataSync**
#   - Schedule **daily transfers** from on-prem → S3
#   - Simple setup, low management
#
# ---
#
# ## ⚠️ When NOT to use DMS
# - CDC not required
# - Complex setup unnecessary
#
# ---
#
# ## ⚡ Optional Enhancement
# - Convert to **Parquet via Glue job** if needed
#
# ---
#
# ## 💡 Exam Hint
# Simple daily ingestion (no CDC) → **DataSync**

# %% [markdown]
# ## ❓ Question
# A system must ingest ~10,000 geolocation events/sec (10 bytes each) into Kinesis Data Streams and maximize shard throughput efficiency with minimal ops. A few minutes delay is acceptable. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Kinesis Throughput Optimization
#
# ---
#
# ## 🛠️ Services
# - Amazon Kinesis Data Streams
# - Kinesis Producer Library (KPL)
#
# ---
#
# ## ⚠️ Issue
# Small records → inefficient shard utilization.
#
# ---
#
# ## ✅ Solution
# - Use **Kinesis Producer Library (KPL)**
# - Enable:
#   - **Aggregation** (combine multiple records into one)
#   - **Batching**
#
# ---
#
# ## ⚡ Why this works
# - Reduces per-record overhead
# - Maximizes shard throughput
# - Improves cost efficiency
#
# ---
#
# ## 💡 Exam Hint
# Small records + high throughput → **KPL aggregation**

# %% [markdown]
# ## ❓ Question
# An e-commerce company needs hourly visibility of orders across multiple AWS-hosted systems (JDBC-compliant DBs) capturing the latest state, with minimal custom development. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Federated Query / Data Integration
#
# ---
#
# ## 🛠️ Services
# - Amazon Athena
# - Athena Federated Query (Lambda connectors)
#
# ---
#
# ## ⚠️ Issue
# Multiple databases → need unified view without heavy ETL.
#
# ---
#
# ## ✅ Solution
# - Use **Athena Federated Query**
# - Query multiple JDBC sources using SQL
# - Get **latest data in real-time (no replication)**
#
# ---
#
# ## ⚡ Why this fits
# - No data movement
# - Minimal setup
# - Serverless
#
# ---
#
# ## 💡 Exam Hint
# Multiple DBs + minimal ETL → **Athena Federated Query**

# %% [markdown]
# ## ❓ Question
# A data engineer needs to develop graph applications using Amazon Neptune. Which programming/query languages should be used?
#
# ---
#
# ## 📌 Topic
# Graph Query Languages
#
# ---
#
# ## 🛠️ Services
# - Amazon Neptune
#
# ---
#
# ## ⚠️ Requirement
# Work with graph data (relationships, traversals).
#
# ---
#
# ## ✅ Supported Languages
# - **Gremlin** → Property graph queries
# - **SPARQL** → RDF graph queries
#
# ---
#
# ## ⚡ When to use what?
# - **Gremlin** → Traversal-based use cases (social graphs, recommendations)
# - **SPARQL** → Semantic/web data (RDF, knowledge graphs)
#
# ---
#
# ## 💡 Exam Hint
# Neptune query languages → **Gremlin + SPARQL**

# %% [markdown]
# ## ❓ Question
# A gaming company streams 20 KB records from a mobile app to **three internal consumers**, each needing **dedicated throughput** and **high performance per device**. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Streaming Fan-out Optimization
#
# ---
#
# ## 🛠️ Services
# - Amazon Kinesis Data Streams
# - Enhanced Fan-Out
#
# ---
#
# ## ⚠️ Issue
# Multiple consumers competing for shard throughput → performance bottleneck.
#
# ---
#
# ## ✅ Solution
# - Use **Kinesis Data Streams with Enhanced Fan-Out (EFO)**
# - Each consumer gets:
#   - **Dedicated throughput (2 MB/s per shard)**
#   - **Low latency (~70 ms)**
#
# ---
#
# ## ⚡ Why not standard polling?
# - Shared throughput → throttling
# - Higher latency
#
# ---
#
# ## 💡 Exam Hint
# Multiple consumers + dedicated throughput → **Enhanced Fan-Out**

# %% [markdown]
# ## ❓ Question
# Create a new empty Athena table with the same schema as `old_table`. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Schema Copy (Athena)
#
# ---
#
# ## 🛠️ Services
# - Amazon Athena
#
# ---
#
# ## ✅ Solution
# Use **CTAS with no data**:
#
# ```sql
# CREATE TABLE new_table
# AS
# SELECT *
# FROM old_table
# WHERE 1 = 0;

# %% [markdown]
# ## ❓ Question
# Create a new Athena table `cities_usa` containing only U.S. cities from `cities_world`. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Filtering (Athena)
#
# ---
#
# ## 🛠️ Services
# - Amazon Athena
#
# ---
#
# ## ✅ Solution
# Use **CTAS (Create Table As Select)**:
#
# ```sql
# CREATE TABLE cities_usa
# AS
# SELECT *
# FROM cities_world
# WHERE country = 'USA';

# %% [markdown]
# ## ❓ Question
# In a data mesh setup with a central governance account using Lake Formation, how can a Redshift Serverless data product be shared with **selective column access per team**?
#
# ---
#
# ## 📌 Topic
# Fine-Grained Data Sharing (Data Mesh)
#
# ---
#
# ## 🛠️ Services
# - AWS Lake Formation
# - Amazon Redshift Serverless
# - AWS RAM (Resource Access Manager)
#
# ---
#
# ## ⚠️ Issue
# Need cross-account sharing + column-level control.
#
# ---
#
# ## ✅ Solution
# - Register Redshift data in **Lake Formation**
# - Use **Lake Formation column-level permissions**
# - Share data via **AWS RAM** to consumer accounts
# - Grant access per team with specific column permissions
#
# ---
#
# ## ⚡ Why this works
# - Central governance
# - Fine-grained access (column-level)
# - Native data mesh pattern
#
# ---
#
# ## 💡 Exam Hint
# Cross-account + column-level → **Lake Formation + RAM**

# %% [markdown]
# ## ❓ Question
# A company uses AWS Glue for ETL and wants data quality checks to run automatically during each pipeline execution with minimal effort. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Automated Data Quality
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
# - AWS Glue Data Quality
#
# ---
#
# ## ⚠️ Issue
# Need automated validation without adding custom logic.
#
# ---
#
# ## ✅ Solution
# - Use **Glue Data Quality rulesets**
# - Attach rulesets directly to **Glue ETL jobs**
# - Run checks automatically during execution
#
# ---
#
# ## ⚡ Benefits
# - No custom validation code
# - Built-in metrics & monitoring
# - Easy reuse across pipelines
#
# ---
#
# ## 💡 Exam Hint
# Auto data quality in Glue → **Glue Data Quality**

# %% [markdown]
# ## ❓ Question
# A microservices app on EKS needs to monitor logs and traces to identify failures across end-to-end requests with minimal development effort. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Observability (Logs + Tracing)
#
# ---
#
# ## 🛠️ Services
# - AWS X-Ray
# - Amazon CloudWatch Logs
# - CloudWatch Container Insights
#
# ---
#
# ## ⚠️ Issue
# Need distributed tracing + logging with low effort.
#
# ---
#
# ## ✅ Solution
# - Use **AWS X-Ray** for distributed tracing
# - Use **CloudWatch Logs + Container Insights** for logs/metrics
# - Enable EKS integrations (minimal code changes)
#
# ---
#
# ## ⚡ Why this works
# - End-to-end request tracing
# - Centralized logs & metrics
# - Managed, low operational overhead
#
# ---
#
# ## 💡 Exam Hint
# Tracing + minimal effort → **X-Ray + CloudWatch**

# %% [markdown]
# ## 🚀 Fluent Bit vs OpenTelemetry (Super Clear)
#
# ---
#
# ## 📌 Fluent Bit
# 👉 **Log collector (lightweight agent)**
#
# ### Use when:
# - You need to **collect logs** from containers (EKS, ECS)
# - Ship logs to:
#   - CloudWatch
#   - OpenSearch
#   - S3
#
# ### Key Points:
# - Very **lightweight & fast**
# - Runs as **DaemonSet in EKS**
# - Focus = **logs only**
#
# ---
#
# ## 📌 OpenTelemetry (OTel)
# 👉 **Observability framework (logs + metrics + traces)**
#
# ### Use when:
# - You need **distributed tracing**
# - Want **metrics + traces + logs in one framework**
# - Need **end-to-end visibility**
#
# ### Key Points:
# - Standardized telemetry (vendor-neutral)
# - Works with:
#   - AWS X-Ray
#   - Prometheus
#   - CloudWatch
#
# ---
#
# ## 🔥 In EKS (Real-world Setup)
#
# | Need | Tool |
# |------|------|
# | Logs only | Fluent Bit |
# | Traces (microservices) | OpenTelemetry |
# | Full observability | Fluent Bit + OTel |
#
# ---
#
# ## ⚡ Example Architecture
# - **Fluent Bit** → sends logs to CloudWatch
# - **OpenTelemetry Collector** → sends traces to X-Ray
#
# ---
#
# ## 🧠 Exam Shortcut
# - Logs → **Fluent Bit**
# - Tracing → **OpenTelemetry**
# - End-to-end debugging → **OTel (with X-Ray)**
#
# ---

# %% [markdown]
# ## ❓ Question
# Continuously stream game data from DynamoDB to OpenSearch so updates appear in near real time. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Streaming Integration (DynamoDB → OpenSearch)
#
# ---
#
# ## 🛠️ Services
# - Amazon DynamoDB
# - DynamoDB Streams
# - AWS Lambda
# - Amazon OpenSearch Service
#
# ---
#
# ## ⚠️ Issue
# Need near real-time sync of updates.
#
# ---
#
# ## ✅ Solution
# - Enable **DynamoDB Streams**
# - Trigger **Lambda** on stream events
# - Lambda indexes data into **OpenSearch**
#
# ---
#
# ## ⚡ Why this works
# - Event-driven
# - Near real-time updates
# - Minimal infrastructure
#
# ---
#
# ## ⚠️ Alternative
# - Use **Kinesis Data Streams + Firehose → OpenSearch** (more complex)
#
# ---
#
# ## 💡 Exam Hint
# DynamoDB → OpenSearch → **Streams + Lambda**

# %% [markdown]
# ## ❓ Question
# A company has data in Redshift, Teradata, and BigQuery. They want to aggregate everything into a central S3 data lake using Apache Iceberg with minimal operations. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Multi-Source Ingestion (Low Ops Data Lake)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - AWS Glue
# - AWS Glue Data Catalog
# - Apache Iceberg
# - AWS Glue Connectors / JDBC
#
# ---
#
# ## ⚠️ Issue
# Multiple heterogeneous sources → need unified ingestion with low ops.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Glue ETL jobs**
#   - Connect to:
#     - Redshift
#     - Teradata
#     - BigQuery (via connectors)
#   - Transform and write to **S3 in Apache Iceberg format**
# - Use **Glue Data Catalog** to manage Iceberg tables
#
# ---
#
# ## ⚡ Why this works
# - Serverless
# - Supports multiple connectors
# - Native Iceberg support in Glue
#
# ---
#
# ## 💡 Exam Hint
# Multi-source → S3 Iceberg → **Glue ETL**

# %% [markdown]
# ## ❓ Question
# An EKS-based app writes to DynamoDB. Containers must securely access DynamoDB **without storing AWS credentials**. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Secure Access (No Credentials)
#
# ---
#
# ## 🛠️ Services
# - Amazon EKS
# - AWS IAM
# - IAM Roles for Service Accounts (IRSA)
# - Amazon DynamoDB
#
# ---
#
# ## ⚠️ Issue
# Avoid hardcoding credentials in containers.
#
# ---
#
# ## ✅ Solution
# - Use **IAM Roles for Service Accounts (IRSA)**
#   - Create IAM role with DynamoDB permissions
#   - Attach role to Kubernetes service account
#   - Pods assume role via OIDC
#
# ---
#
# ## ⚡ Why this works
# - No credentials stored in code
# - Fine-grained IAM access
# - Native Kubernetes integration
#
# ---
#
# ## 💡 Exam Hint
# EKS + no credentials → **IRSA**

# %% [markdown]
# ## ❓ Question
# A data producer must migrate data from an on-prem data center to AWS over a **private connection**, without exposing data to the public internet. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Private Connectivity (Hybrid)
#
# ---
#
# ## 🛠️ Services
# - AWS Direct Connect
#
# ---
#
# ## ⚠️ Issue
# Need secure, private, dedicated connection.
#
# ---
#
# ## ✅ Solution
# - Use **AWS Direct Connect**
#   - Dedicated private network link
#   - Bypasses public internet
#   - High bandwidth & low latency
#
# ---
#
# ## ⚡ Optional Enhancement
# - Use **Direct Connect + VPN (for encryption)** if required
#
# ---
#
# ## 💡 Exam Hint
# Private on-prem → AWS → **Direct Connect**

# %% [markdown]
# ## ❓ Question
# Glue Data Catalog must update automatically when new files arrive in S3 using event notifications + SQS, with minimal ops. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Automated Catalog Updates
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - Amazon SQS
# - AWS Glue Crawler
#
# ---
#
# ## ⚠️ Issue
# Need automatic schema/catalog updates on new data arrival.
#
# ---
#
# ## ✅ Solution
# - Configure **S3 Event Notifications → SQS**
# - Trigger **Glue Crawler** from SQS events
# - Crawler updates **Glue Data Catalog automatically**
#
# ---
#
# ## ⚡ Why this works
# - Event-driven
# - No manual runs
# - Minimal maintenance
#
# ---
#
# ## 💡 Exam Hint
# Auto catalog update → **S3 Event + Glue Crawler**

# %% [markdown]
# ## ❓ Question
# A company stores PII in Redshift and must give different access levels to marketing, claims, and analytics teams with minimal admin effort. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Fine-Grained Access Control (Redshift)
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
# - Role-Based Access Control (RBAC)
# - Column-Level Security (CLS)
# - Row-Level Security (RLS)
#
# ---
#
# ## ⚠️ Issue
# Different teams → different access to sensitive (PII) data.
#
# ---
#
# ## ✅ Solution
# - Use **Redshift RBAC**
# - Implement:
#   - **Column-Level Security** → hide PII columns
#   - **Row-Level Security** → restrict rows if needed
# - Assign roles to teams (marketing, claims, analytics)
#
# ---
#
# ## ⚡ Why this works
# - Centralized control
# - Minimal manual management
# - Fine-grained permissions
#
# ---
#
# ## 💡 Exam Hint
# PII + multiple teams → **Redshift RBAC + CLS/RLS**

# %% [markdown]
# ## ❓ Question
# After adding new topics to an MSK cluster, a CloudWatch alarm triggers on **RootDiskUsed**. What is the issue and solution?
#
# ---
#
# ## 📌 Topic
# Storage Management (MSK / Kafka)
#
# ---
#
# ## 🛠️ Services
# - Amazon MSK
# - Amazon CloudWatch
#
# ---
#
# ## ⚠️ Issue
# - New topics → more partitions → more data/logs
# - Broker disk usage increases → root volume fills up
#
# ---
#
# ## ✅ Solution
# - **Increase broker storage (EBS volume size)**
# - Optionally:
#   - Adjust **retention settings** (`retention.ms`, `retention.bytes`)
#   - Enable **log compaction** if applicable
#
# ---
#
# ## ⚡ Why this happens
# Kafka stores:
# - Topic partitions
# - Replication copies
# - Logs on broker disks
#
# ---
#
# ## 💡 Exam Hint
# MSK disk full → **Increase storage or reduce retention**

# %% [markdown]
# ## ❓ Question
# How to prevent overwriting good data in Glue ETL when incoming data may be incomplete or invalid?
#
# ---
#
# ## 📌 Topic
# Data Quality Enforcement
#
# ---
#
# ## 🛠️ Services
# - AWS Glue Data Quality
# - DQDL (Data Quality Definition Language)
#
# ---
#
# ## ⚠️ Issue
# Bad/incomplete data overwrites valid datasets.
#
# ---
#
# ## ✅ Solution
# - Use **Glue Data Quality rules (DQDL)**
# - Validate:
#   - Completeness
#   - Required fields
# - Only proceed if checks pass
#
# ---
#
# ## ⚡ Key Benefits
# - Declarative rules (no heavy coding)
# - Seamless integration with Glue ETL
# - Prevents bad data overwrite automatically
#
# ---
#
# ## 💡 Exam Hint
# Prevent bad data overwrite → **Glue Data Quality (DQDL)**

# %% [markdown]
# ## 🚀 Amazon S3 Storage Lens (Quick & Clear)
#
# ---
#
# ## 📌 What is it?
# 👉 **Organization-wide visibility tool for S3**
#
# - Monitors **usage, activity, cost, and data protection**
# - Works across:
#   - Multiple buckets
#   - Multiple accounts
#
# ---
#
# ## 📊 What it helps you find
# - Incomplete multipart uploads
# - Old object versions
# - Storage growth trends
# - Access patterns
# - Encryption & security gaps
#
# ---
#
# ## 🆚 Storage Lens vs Inventory
#
# | Feature | Storage Lens | S3 Inventory |
# |--------|-------------|-------------|
# | Scope | Org / Account-wide | Bucket-level |
# | Use case | Monitoring + insights | Detailed object list |
# | Frequency | Daily metrics | Daily/weekly reports |
# | Visualization | Dashboard | Raw files (CSV/Parquet) |
#
# ---
#
# ## ✅ When to use Storage Lens
# - Need **centralized dashboard**
# - Want **trends & insights**
# - Managing **multiple buckets/accounts**
#
# ---
#
# ## ⚠️ When NOT enough
# - Need exact object-level list → use **Inventory**
#
# ---
#
# ## 🧠 Exam Shortcut
# - Insights/dashboard → **Storage Lens**
# - Detailed object list → **Inventory**
# - Cleanup multipart → **Lifecycle rules**
#
# ---

# %% [markdown]
# ## ❓ Question
# Kinesis Firehose delivers JSON to S3. Athena costs are high due to small JSON files. Need to reduce cost without rebuilding pipeline. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Cost Optimization (Athena + Firehose)
#
# ---
#
# ## 🛠️ Services
# - Amazon Kinesis Data Firehose
# - Amazon S3
# - Amazon Athena
#
# ---
#
# ## ⚠️ Issue
# - Small JSON files → high scan cost
# - Inefficient query performance
#
# ---
#
# ## ✅ Solution
# - Enable **Firehose Data Format Conversion**
#   - Convert **JSON → Parquet (or ORC)**
# - Increase **buffer size/time** in Firehose to create larger files
#
# ---
#
# ## ⚡ Why this works
# - Columnar formats → less data scanned
# - Larger files → fewer reads
#
# ---
#
# ## 💡 Exam Hint
# Athena cost high + JSON → **Convert to Parquet via Firehose**

# %% [markdown]
# ## ❓ Question
# Multiple Regional EFS file systems exist, but data must be processed in one Region with minimal effort. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Cross-Region Data Consolidation
#
# ---
#
# ## 🛠️ Services
# - Amazon EFS
# - AWS DataSync
#
# ---
#
# ## ⚠️ Issue
# EFS is regional → cannot directly access across Regions.
#
# ---
#
# ## ✅ Solution
# - Use **AWS DataSync**
#   - Transfer data from multiple EFS file systems
#   - Consolidate into a **single EFS (or S3) in one Region**
# - Schedule or automate sync
#
# ---
#
# ## ⚡ Why this works
# - Fully managed
# - Fast and efficient transfer
# - Minimal operational overhead
#
# ---
#
# ## 💡 Exam Hint
# EFS cross-region transfer → **DataSync**

# %% [markdown]
# ## ❓ Question
# Data in S3 is already encrypted with KMS. While processing via EMR, ensure **encryption at rest and in transit**, using a PEM file stored in S3. What is the best solution?
#
# ---
#
# ## 📌 Topic
# End-to-End Encryption (EMR)
#
# ---
#
# ## 🛠️ Services
# - Amazon EMR
# - Amazon S3
# - AWS KMS
#
# ---
#
# ## ⚠️ Requirements
# - Encryption at rest ✅ (already via KMS)
# - Encryption in transit ❗
#
# ---
#
# ## ✅ Solution
# - Enable **EMR Security Configuration**
#   - Turn on:
#     - **At-rest encryption (KMS)**
#     - **In-transit encryption (TLS)**
# - Provide **PEM certificate (from S3)** for TLS
#
# ---
#
# ## ⚡ Why this works
# - Centralized encryption config
# - Ensures:
#   - Node-to-node encryption
#   - Client-to-cluster encryption
#
# ---
#
# ## 💡 Exam Hint
# EMR encryption → **Security Configuration + PEM (TLS)**

# %% [markdown]
# ## ❓ Question
# A company uses Redshift for real-time analytics and has a SageMaker real-time endpoint. They want predictions (recommendations + inventory forecasting) directly from within Redshift. What is the best solution?
#
# ---
#
# ## 📌 Topic
# ML Integration with Redshift
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
# - Amazon SageMaker
#
# ---
#
# ## ⚠️ Issue
# Need real-time ML inference **inside Redshift queries**.
#
# ---
#
# ## ✅ Solution
# - Use **Redshift ML (remote inference)**
#   - Integrate with **SageMaker endpoint**
# - Call predictions directly in SQL
#
# ---
#
# ## ⚡ Example
# ```sql
# SELECT *,
#        PREDICT(model_name, features)
# FROM table;

# %% [markdown]
# ## ❓ Question
# Redshift tables have suboptimal compression encoding, causing inefficient storage and slow queries. How to determine and apply better encoding?
#
# ---
#
# ## 📌 Topic
# Compression Optimization (Redshift)
#
# ---
#
# ## 🛠️ Services
# - Amazon Redshift
#
# ---
#
# ## ⚠️ Issue
# Wrong encoding → more storage + slower scans.
#
# ---
#
# ## ✅ Solution
# - Run **ANALYZE COMPRESSION**
#   - Determines optimal encoding per column
# - Apply results:
#   - Recreate table with recommended encodings
#   - Or use **ALTER TABLE / COPY with ENCODE AUTO**
#
# ---
#
# ## ⚡ Modern Approach
# - Use **ENCODE AUTO**
#   - Redshift automatically manages encoding
#
# ---
#
# ## 💡 Exam Hint
# Find best encoding → **ANALYZE COMPRESSION**

# %% [markdown]
# ## ❓ Question
# In QuickSight, a dashboard shows revenue by Region. Even when users drill down (e.g., country → city), it must **always display total revenue at Region level**. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Level-Aware Calculations (QuickSight)
#
# ---
#
# ## 🛠️ Services
# - Amazon QuickSight
#
# ---
#
# ## ⚠️ Issue
# Drill-down changes aggregation level → Region total gets lost.
#
# ---
#
# ## ✅ Solution
# - Use **Level-Aware Calculation (LAC-A)**
#
# ```sql
# sumOver({revenue}, [{Region}], PRE_AGG)

# %% [markdown]
# ## ❓ Question
# CloudTrail logs are stored in S3, cataloged in Glue, partitioned by year. Athena query returns no data. What is the issue and fix?
#
# ---
#
# ## 📌 Topic
# Partition Management (Athena)
#
# ---
#
# ## 🛠️ Services
# - Amazon S3
# - AWS Glue Data Catalog
# - Amazon Athena
#
# ---
#
# ## ⚠️ Issue
# Partitions exist in S3 but are **not registered in Glue Catalog**.
#
# ---
#
# ## ✅ Solution
# - Run:
#
# ```sql
# MSCK REPAIR TABLE table_name;

# %% [markdown]
# ## ❓ Question
# A company enforces strict IAM-based access on S3 and wants **notifications when access policies are violated**, including the **username responsible**. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Security Monitoring & Alerts
#
# ---
#
# ## 🛠️ Services
# - AWS CloudTrail
# - Amazon EventBridge
# - Amazon SNS
#
# ---
#
# ## ⚠️ Issue
# Need real-time alerting on unauthorized/denied access.
#
# ---
#
# ## ✅ Solution
# - Enable **CloudTrail** (logs all API calls, including denied)
# - Create **EventBridge rule**:
#   - Filter: `errorCode = AccessDenied`
# - Send event to **SNS** for notification
#
# ---
#
# ## ⚡ Why this works
# - CloudTrail logs include:
#   - User identity
#   - Action attempted
#   - Error (AccessDenied)
# - EventBridge enables near real-time alerts
#
# ---
#
# ## 💡 Exam Hint
# Access denied alert + user info → **CloudTrail + EventBridge + SNS**

# %% [markdown]
# ## 🚀 SUPER Data Type (Super Simple Explanation)
#
# Think of **SUPER** like:
# 👉 "Store JSON directly in Redshift and query it like SQL"
#
# ---
#
# ## 📌 Step 1: Create Table
#
# ```sql
# CREATE TABLE customers (
#     id INT,
#     info SUPER
# );

# %% [markdown]
# INSERT INTO customers VALUES
# (1, '{"name":"Shubham","age":25,"city":"Delhi"}'),
# (2, '{"name":"Amit","age":30,"city":"Mumbai"}');

# %% [markdown]
# SELECT info.name FROM customers;

# %% [markdown]
# ## ❓ Question
# A Step Functions workflow must execute different steps based on incoming data content (API → transform → DynamoDB). What is the best solution?
#
# ---
#
# ## 📌 Topic
# Conditional Workflow (Step Functions)
#
# ---
#
# ## 🛠️ Services
# - AWS Step Functions
# - AWS Lambda
# - Amazon DynamoDB
#
# ---
#
# ## ⚠️ Issue
# Workflow needs **dynamic branching based on data**.
#
# ---
#
# ## ✅ Solution
# - Use **Choice State** in Step Functions
# - Define conditions to route execution paths
#
# ---
#
# ## ⚡ Example Flow

# %% [markdown]
# ## ❓ Question
# A company uses DataZone + Glue + S3 and wants to publish **Glue Data Quality scores** to the DataZone portal. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Governance Integration
#
# ---
#
# ## 🛠️ Services
# - Amazon DataZone
# - AWS Glue Data Quality
# - AWS Glue Data Catalog
#
# ---
#
# ## ⚠️ Issue
# Need to expose data quality metrics in governance portal.
#
# ---
#
# ## ✅ Solution
# - Enable **integration between Glue Data Quality and DataZone**
# - Publish **Data Quality results to Data Catalog**
# - DataZone automatically surfaces:
#   - Quality scores
#   - Metadata
# ## ❓ Question
# Migrate a data warehouse from Teradata to Amazon Redshift with minimal operational effort. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Warehouse Migration
#
# ---
#
# ## 🛠️ Services
# - AWS Schema Conversion Tool (SCT)
# - AWS Database Migration Service (DMS)
#
# ---
#
# ## ⚠️ Issue
# Need schema + data migration with low manual effort.
#
# ---
#
# ## ✅ Solution
# 1. Use **AWS SCT**
#    - Convert Teradata schema → Redshift schema
#
# 2. Use **AWS DMS**
#    - Migrate data (full load + optional CDC)
#
# ---
#
# ## ⚡ Why this works
# - Automated schema conversion
# - Minimal downtime
# - Managed migration
#
# ---
#
# ## 💡 Exam Hint
# Warehouse migration → **SCT + DMS**
#
# ---
#
# ## ⚡ Why this works
# - Native integration
# - No custom pipeline needed
# - Centralized governance visibility
#
# ---
#
# ## 💡 Exam Hint
# Glue DQ → DataZone → **Native integration (no custom code)**

# %% [markdown]
# ## ❓ Question
# An API Lambda is throttled when other Lambdas spike usage in the same account. Need to isolate it cost-effectively. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Lambda Concurrency Control
#
# ---
#
# ## 🛠️ Services
# - AWS Lambda
#
# ---
#
# ## ⚠️ Issue
# All Lambdas share account concurrency → noisy neighbor problem.
#
# ---
#
# ## ✅ Solution
# - Configure **Reserved Concurrency** for the API Lambda
#
# ---
#
# ## ⚡ Why this works
# - Guarantees dedicated concurrency
# - Prevents other Lambdas from consuming its capacity
# - Cost-effective (no extra infrastructure)
#
# ---
#
# ## ⚠️ Alternative (less ideal)
# - Provisioned concurrency (costlier, for latency use case)
#
# ---
#
# ## 💡 Exam Hint
# Lambda isolation → **Reserved Concurrency**

# %% [markdown]
# ## ❓ Question
# Two datasets (primary & reference) contain city/state columns. Need to ensure values in primary **exactly match** reference using Glue Data Quality (DQDL). What is the best approach?
#
# ---
#
# ## 📌 Topic
# Referential Data Quality Validation
#
# ---
#
# ## 🛠️ Services
# - AWS Glue Data Quality
# - DQDL (Data Quality Definition Language)
#
# ---
#
# ## ⚠️ Issue
# Need cross-dataset validation (not just within one dataset).
#
# ---
#
# ## ✅ Solution
# - Use **Referential Integrity rule in DQDL**
#
# ### Example Concept
# ```text
# DatasetMatch "primary.city = reference.city AND primary.state = reference.state"

# %% [markdown]
# ## ❓ Question
# Billions of orders in Aurora need near real-time reporting by joining with a Redshift table, with minimal latency and **no impact on Aurora**. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Zero-ETL Integration
#
# ---
#
# ## 🛠️ Services
# - Amazon Aurora
# - Amazon Redshift
#
# ---
#
# ## ⚠️ Issue
# - Direct querying Aurora → performance impact
# - Need near real-time sync
#
# ---
#
# ## ✅ Solution
# - Use **Aurora → Redshift Zero-ETL Integration**
#
# ---
#
# ## ⚡ Why this works
# - Near real-time replication
# - No ETL pipelines
# - No load on Aurora queries
# - Seamless querying inside Redshift
#
# ---
#
# ## 💡 Exam Hint
# Aurora + Redshift + no impact → **Zero-ETL integration**

# %% [markdown]
# ## ❓ Question
# A company wants a data catalog for their data lake + warehouse that supports **business metadata and glossaries** with minimal operational overhead. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Data Governance & Catalog
#
# ---
#
# ## 🛠️ Services
# - Amazon DataZone
#
# ---
#
# ## ⚠️ Issue
# Need business-friendly catalog (not just technical metadata).
#
# ---
#
# ## ✅ Solution
# - Use **Amazon DataZone**
#   - Supports:
#     - Business metadata
#     - Data glossaries
#     - Data discovery
#   - Low operational overhead (managed service)
#
# ---
#
# ## ⚡ Why not Glue Catalog?
# - Glue = technical metadata
# - DataZone = **business + governance layer**
#
# ---
#
# ## 💡 Exam Hint
# Business catalog + glossary → **DataZone**

# %% [markdown]
# ## ❓ Question
# An AWS Glue Spark ETL job fails with **"No space left on device"**. Fix it cost-effectively. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Glue Resource Optimization
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
#
# ---
#
# ## ⚠️ Issue
# - Spark uses local disk for:
#   - Shuffle
#   - Spill
# - Disk space exhausted
#
# ---
#
# ## ✅ Solution
# - Increase **number of workers (horizontal scaling)**
#   👉 More workers = more aggregate disk space
#
# ---
#
# ## ⚡ Why NOT just bigger workers?
# - Increasing worker type (vertical scaling) = higher cost
# - More workers = **cost-efficient scaling + distributed load**
#
# ---
#
# ## ⚡ Additional Tips
# - Reduce shuffle:
#   - Use **partitioning**
#   - Filter early
# - Use **pushdown predicates**
#
# ---
#
# ## 💡 Exam Hint
# Glue "no space left" → **Increase workers (not size)**

# %% [markdown]
# ## ❓ Question
# Glue job faces small files problem. What is the best cost-effective solution?
#
# ---
#
# ## 📌 Topic
# Small File Optimization (Glue)
#
# ---
#
# ## 🛠️ Services
# - AWS Glue
#
# ---
#
# ## ⚠️ Issue
# - Many small files → poor Spark performance
# - High overhead → slower jobs
#
# ---
#
# ## ✅ Solution
# - Use **DynamicFrame grouping option**
#
# ```python
# connection_options = {
#   "groupFiles": "inPartition",
#   "groupSize": "134217728"  # ~128 MB
# }

# %% [markdown]
# ## ❓ Question
# Applications generate logs. Need to **query and visualize logs in near real time** with minimal delay. What is the best solution?
#
# ---
#
# ## 📌 Topic
# Real-Time Log Analytics
#
# ---
#
# ## 🛠️ Services
# - Amazon OpenSearch Service
# - Amazon Kinesis Data Firehose / Streams
# - Amazon CloudWatch Logs
#
# ---
#
# ## ⚠️ Issue
# Need fast ingestion + real-time querying + visualization.
#
# ---
#
# ## ✅ Solution
# - Stream logs to **Amazon OpenSearch Service**
#   - Via **Kinesis Data Firehose** or **CloudWatch subscription**
# - Use **OpenSearch Dashboards** for visualization
#
# ---
#
# ## ⚡ Why this works
# - Near real-time indexing
# - Built-in dashboards
# - Minimal setup
#
# ---
#
# ## 💡 Exam Hint
# Real-time logs + visualization → **OpenSearch**

# %% [markdown]
# ## 🌐 Amazon QuickSight Port
#
# - **Protocol:** HTTPS
# - **Port:** 443
#
# ---
#
# ## 📌 Key Points
# - It’s a **fully managed SaaS service**
# - Access via browser → no port configuration needed
# - Example URL:
#   https://quicksight.aws.amazon.com
#
# ---
#
# ## ⚠️ When ports matter
# Only for **data sources** QuickSight connects to:
#
# | Data Source | Default Port |
# |------------|-------------|
# | Redshift | 5439 |
# | PostgreSQL | 5432 |
# | MySQL | 3306 |
# | SQL Server | 1433 |
#
# ---
#
# ## 💡 Exam Trick
# QuickSight itself → **443 (HTTPS)**
# Data source → **DB-specific ports**
#
# ---

# %% [markdown]
# ## 🚀 Amazon Storage Gateway (Quick & Clear)
#
# ---
#
# ## 📌 What is it?
# 👉 A **hybrid storage service** that connects **on-prem systems ↔ AWS storage (S3 / Glacier / EBS)**
#
# ---
#
# ## 🧠 Why use it?
# - Extend on-prem storage to cloud
# - Backup & archive data
# - Low latency local access + cloud durability
#
# ---
#
# ## 🛠️ Types of Storage Gateway
#
# ### 1️⃣ File Gateway
# 👉 NFS / SMB interface → stores files in S3
#
# **Use when:**
# - Lift & shift file shares to S3
# - Data lake ingestion
#
# ---
#
# ### 2️⃣ Volume Gateway
# 👉 Block storage (iSCSI)
#
# Two modes:
# - **Cached Volume** → data in S3, cache locally
# - **Stored Volume** → full data on-prem + backup to AWS
#
# **Use when:**
# - Backup on-prem apps to cloud
#
# ---
#
# ### 3️⃣ Tape Gateway
# 👉 Virtual tape library (VTL)
#
# **Use when:**
# - Replace physical tape backups
# - Archive to S3 Glacier
#
# ---
#
# ## ⚡ Architecture Idea
# On-prem app → Storage Gateway → AWS (S3/Glacier)
#
# ---
#
# ## 🔥 Quick Comparison
#
# | Gateway | Interface | Backend | Use Case |
# |--------|----------|--------|---------|
# | File | NFS/SMB | S3 | File share → cloud |
# | Volume | iSCSI | S3 + EBS snapshots | Backup/DR |
# | Tape | VTL | Glacier | Tape replacement |
#
# ---
#
# ## 💡 Exam Shortcuts
# - File share → **File Gateway**
# - Backup volumes → **Volume Gateway**
# - Tape replacement → **Tape Gateway**
#
# ---

# %% [markdown]
# ## 🚀 AWS DMS vs DataSync (Crystal Clear)
#
# ---
#
# ## 📌 Core Difference
#
# | Feature | AWS DMS | AWS DataSync |
# |--------|--------|-------------|
# | Data Type | Databases | Files / objects |
# | Use Case | DB migration & replication | File transfer |
# | CDC Support | ✅ Yes | ❌ No |
# | Schema Handling | ❌ (needs SCT) | ❌ |
# | Protocol | DB engines | NFS, SMB, S3, EFS, FSx |
#
# ---
#
# ## 🛠️ AWS DMS (Database Migration Service)
#
# 👉 **Use when:**
# - Migrating databases (Oracle, MySQL, PostgreSQL, etc.)
# - Need **continuous replication (CDC)**
#
# ### Example:
# - Oracle → Aurora
# - MySQL → Redshift
#
# ### Key Features:
# - Full load + CDC
# - Minimal downtime
#
# ---
#
# ## 🛠️ AWS DataSync
#
# 👉 **Use when:**
# - Moving **files / folders**
# - On-prem → S3 / EFS / FSx
#
# ### Example:
# - NAS → S3
# - EFS → EFS (cross-region)
#
# ### Key Features:
# - Fast, parallel transfer
# - Scheduling
# - No database logic
#
# ---
#
# ## ⚠️ Common Confusion
#
# | Scenario | Correct Service |
# |---------|----------------|
# | Database migration | DMS |
# | File migration | DataSync |
# | Continuous updates (CDC) | DMS |
# | Daily file sync | DataSync |
#
# ---
#
# ## 🧠 Exam Shortcut
# - DB → **DMS**
# - Files → **DataSync**
# - CDC → **DMS**
# - NFS/SMB → **DataSync**
#
# ---

# %% [markdown]
# ## 🚀 Amazon API Gateway (Quick & Exam-Focused)
#
# ---
#
# ## 📌 What is it?
# 👉 Fully managed service to **create, publish, secure, and monitor APIs**
#
# - Supports:
#   - **REST APIs**
#   - **HTTP APIs (lighter, cheaper)**
#   - **WebSocket APIs (real-time)**
#
# ---
#
# ## 🧠 Why use it?
# - Expose backend (Lambda, EC2, services) as APIs
# - Handle **auth, throttling, caching, monitoring**
# - Fully serverless
#
# ---
#
# ## 🛠️ Integrations
#
# | Backend | Supported |
# |--------|----------|
# | AWS Lambda | ✅ (most common) |
# | HTTP endpoints | ✅ |
# | AWS services (S3, DynamoDB) | ✅ |
# | VPC services (via VPC Link) | ✅ |
#
# ---
#
# ## 🔐 Security Options
#
# - **IAM Auth**
# - **Cognito User Pools**
# - **Lambda Authorizer**
# - **API Keys + Usage Plans**
# - **WAF integration**
#
# ---
#
# ## ⚡ Key Features
#
# - **Throttling** → protect backend
# - **Caching** → reduce latency
# - **Stages** → dev / test / prod
# - **Request/Response transformation**
# - **Monitoring via CloudWatch**
#
# ---
#
# ## 🌐 Endpoints
#
# | Type | Use |
# |------|-----|
# | Edge-optimized | Global APIs (via CloudFront) |
# | Regional | Region-specific |
# | Private | Inside VPC only |
#
# ---
#
# ## 🔥 Common Patterns
#
# ### 1️⃣ Serverless API
# API Gateway → Lambda → DynamoDB
#
# ### 2️⃣ Microservices
# API Gateway → multiple services
#
# ### 3️⃣ Private API
# API Gateway (Private) → VPC backend
#
# ---
#
# ## ⚠️ REST vs HTTP API
#
# | Feature | REST API | HTTP API |
# |--------|---------|----------|
# | Cost | Higher | Lower |
# | Features | Full | Limited |
# | Use case | Complex APIs | Simple APIs |
#
# ---
#
# ## 🧠 Exam Shortcuts
# - Lambda + API → **API Gateway**
# - Real-time → **WebSocket API**
# - Cheap/simple → **HTTP API**
# - Private access → **Private API + VPC Link**
#
# ---

# %% [markdown]
# ## 🚀 AWS Batch (Quick & Exam-Focused)
#
# ---
#
# ## 📌 What is it?
# 👉 Fully managed service to **run batch computing jobs at scale**
#
# - Runs jobs as **Docker containers**
# - Automatically provisions compute (EC2 / Fargate)
#
# ---
#
# ## 🧠 When to use it?
# - Large-scale **batch processing**
# - Jobs that:
#   - Run asynchronously
#   - Don’t need real-time response
#   - Can be queued
#
# ### Examples:
# - ETL jobs
# - Image/video processing
# - Scientific simulations
#
# ---
#
# ## 🛠️ Core Components
#
# ### 1️⃣ Job
# - Unit of work (containerized task)
#
# ### 2️⃣ Job Queue
# - Where jobs wait before execution
#
# ### 3️⃣ Compute Environment
# - Underlying compute:
#   - EC2 (On-Demand / Spot)
#   - Fargate
#
# ---
#
# ## ⚙️ Flow
#
# ---
#
# ## ⚡ Key Features
#
# - Auto scaling compute
# - Supports **Spot instances** → cost savings 💰
# - Handles job retries & dependencies
# - No need to manage clusters
#
# ---
#
# ## 🔥 EC2 vs Fargate
#
# | Feature | EC2 | Fargate |
# |--------|-----|---------|
# | Control | More | Less |
# | Cost | Cheaper (Spot) | Higher |
# | Ops | More | Minimal |
#
# ---
#
# ## ⚠️ When NOT to use
# - Real-time processing → use Lambda / Kinesis
# - Simple scripts → use Lambda
#
# ---
#
# ## 🧠 Exam Shortcuts
# - Batch jobs + containers → **AWS Batch**
# - Queue-based processing → **Batch**
# - Cost optimization → **Batch + Spot**
#
# ---
